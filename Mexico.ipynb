# %%
#Instalamos 
# %pip install funpymodeling
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting funpymodeling
#   Using cached funpymodeling-0.1.9-py3-none-any.whl.metadata (1.3 kB)
# Collecting flake8<7.0.0,>=6.0.0 (from funpymodeling)
#   Using cached flake8-6.1.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting jupyter<2.0.0,>=1.0.0 (from funpymodeling)
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting matplotlib<4.0.0,>=3.7.1 (from funpymodeling)
#   Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting numpy<2.0.0,>=1.26.2 (from funpymodeling)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 217.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 245.8 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 245.8 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 245.8 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 245.8 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 145.2 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 154.4 kB/s eta 0:00:00
# Collecting pandas<3.0.0,>=2.1.4 (from funpymodeling)
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pre-commit<4.0.0,>=3.3.2 (from funpymodeling)
#   Downloading pre_commit-3.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting pytest<8.0.0,>=7.3.1 (from funpymodeling)
#   Downloading pytest-7.4.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting scikit-learn<2.0.0,>=1.2.2 (from funpymodeling)
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting seaborn<0.13.0,>=0.12.2 (from funpymodeling)
#   Downloading seaborn-0.12.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.6.3 in c:\users\valer\appdata\roaming\python\python311\site-packages (from funpymodeling) (4.12.2)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8<7.0.0,>=6.0.0->funpymodeling)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.12.0,>=2.11.0 (from flake8<7.0.0,>=6.0.0->funpymodeling)
#   Downloading pycodestyle-2.11.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.2.0,>=3.1.0 (from flake8<7.0.0,>=6.0.0->funpymodeling)
#   Downloading pyflakes-3.1.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting notebook (from jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.29.5)
# Collecting ipywidgets (from jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyterlab (from jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyterlab-4.3.5-py3-none-any.whl.metadata (16 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl.metadata (103 kB)
#      ---------------------------------------- 0.0/104.0 kB ? eta -:--:--
#      ----------------------- --------------- 61.4/104.0 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 104.0/104.0 kB 1.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (24.2)
# Collecting pillow>=8 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4.0.0,>=3.7.1->funpymodeling)
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\valer\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.1.4->funpymodeling)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.1.4->funpymodeling)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting cfgv>=2.0.0 (from pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading identify-2.6.7-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml>=5.1 (from pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading virtualenv-20.29.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting iniconfig (from pytest<8.0.0,>=7.3.1->funpymodeling)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest<8.0.0,>=7.3.1->funpymodeling)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: colorama in c:\users\valer\appdata\roaming\python\python311\site-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (0.4.6)
# Collecting scipy>=1.6.0 (from scikit-learn<2.0.0,>=1.2.2->funpymodeling)
#   Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn<2.0.0,>=1.2.2->funpymodeling)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.2.2->funpymodeling)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\valer\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.17.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting filelock<4,>=3.12.2 (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (4.3.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.6.0)
# Requirement already satisfied: psutil in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.50)
# Requirement already satisfied: pygments in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.19.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jinja2>=3.0.3 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (65.5.0)
# Collecting beautifulsoup4 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markupsafe>=2.0 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading mistune-3.1.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: decorator in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.6.3)
# Requirement already satisfied: pywin32>=300 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (308)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading pywinpty-2.0.15-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests>=2.31 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wcwidth in c:\users\valer\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.8.4)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading rpds_py-0.22.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading python_json_logger-3.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading funpymodeling-0.1.9-py3-none-any.whl (6.5 kB)
# Downloading flake8-6.1.0-py2.py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.0 MB 6.4 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/8.0 MB 5.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/8.0 MB 7.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.0 MB 10.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.6/8.0 MB 11.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.0 MB 15.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.0 MB 17.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/8.0 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 15.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.8 MB 17.9 MB/s eta 0:00:01
#    ------ --------------------------------- 2.4/15.8 MB 29.9 MB/s eta 0:00:01
#    -------- ------------------------------- 3.6/15.8 MB 28.3 MB/s eta 0:00:01
#    ------------ --------------------------- 5.1/15.8 MB 29.4 MB/s eta 0:00:01
#    ------------ --------------------------- 5.1/15.8 MB 29.7 MB/s eta 0:00:01
#    -------------- ------------------------- 5.8/15.8 MB 23.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.7/15.8 MB 22.4 MB/s eta 0:00:01
#    ------------------ --------------------- 7.4/15.8 MB 21.6 MB/s eta 0:00:01
#    --------------------- ------------------ 8.7/15.8 MB 22.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.5/15.8 MB 21.7 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/15.8 MB 21.8 MB/s eta 0:00:01
#    ------------------------- -------------- 10.3/15.8 MB 21.8 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.8 MB 19.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.5/15.8 MB 19.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.2/15.8 MB 19.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.1/15.8 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.8 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 18.2 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.6 MB 24.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/11.6 MB 20.0 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.6 MB 18.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/11.6 MB 18.4 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.6 MB 18.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.8/11.6 MB 17.9 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.6 MB 18.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.4/11.6 MB 18.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.2/11.6 MB 18.3 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.6 MB 18.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.7/11.6 MB 18.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.6 MB 18.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.6 MB 18.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 16.8 MB/s eta 0:00:00
# Downloading pre_commit-3.8.0-py2.py3-none-any.whl (204 kB)
#    ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#    --------------------------------------- 204.6/204.6 kB 12.2 MB/s eta 0:00:00
# Downloading pytest-7.4.4-py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.3 kB ? eta -:--:--
#    --------------------------------------- 325.3/325.3 kB 10.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.9/11.1 MB 27.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/11.1 MB 21.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.5/11.1 MB 23.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.4/11.1 MB 21.5 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/11.1 MB 20.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.1 MB 18.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.9/11.1 MB 19.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.1 MB 20.1 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.1 MB 19.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.1 MB 19.4 MB/s eta 0:00:01
#    -------------------------------- ------- 9.1/11.1 MB 19.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.1 MB 19.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.1 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 18.2 MB/s eta 0:00:00
# Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#    ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#    ---------------------------------------- 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#    ---------------------------------------- 0.0/219.8 kB ? eta -:--:--
#    --------------------------------------- 219.8/219.8 kB 14.0 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------- ----------------------- 0.9/2.2 MB 29.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 20.1 MB/s eta 0:00:00
# Downloading identify-2.6.7-py2.py3-none-any.whl (99 kB)
#    ---------------------------------------- 0.0/99.1 kB ? eta -:--:--
#    ---------------------------------------- 99.1/99.1 kB 5.6 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ---------------------------------------- 301.8/301.8 kB 9.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB 4.1 MB/s eta 0:00:00
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------- ------------------------- 0.9/2.6 MB 19.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 20.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 16.8 MB/s eta 0:00:00
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading pycodestyle-2.11.1-py2.py3-none-any.whl (31 kB)
# Downloading pyflakes-3.1.0-py2.py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#    ---------------------------------------- 0.0/507.9 kB ? eta -:--:--
#    --------------------------------------- 507.9/507.9 kB 10.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
#    ---------------------------------------- 0.0/162.0 kB ? eta -:--:--
#    --------------------------------------- 162.0/162.0 kB 10.1 MB/s eta 0:00:00
# Downloading scipy-1.15.1-cp311-cp311-win_amd64.whl (43.9 MB)
#    ---------------------------------------- 0.0/43.9 MB ? eta -:--:--
#     --------------------------------------- 0.9/43.9 MB 19.2 MB/s eta 0:00:03
#    - -------------------------------------- 1.8/43.9 MB 19.3 MB/s eta 0:00:03
#    -- ------------------------------------- 2.7/43.9 MB 21.5 MB/s eta 0:00:02
#    --- ------------------------------------ 3.5/43.9 MB 20.0 MB/s eta 0:00:03
#    --- ------------------------------------ 4.0/43.9 MB 18.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.9/43.9 MB 19.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.7/43.9 MB 19.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.6/43.9 MB 19.9 MB/s eta 0:00:02
#    ------ --------------------------------- 7.4/43.9 MB 19.7 MB/s eta 0:00:02
#    ------- -------------------------------- 8.1/43.9 MB 19.1 MB/s eta 0:00:02
#    -------- ------------------------------- 8.9/43.9 MB 19.6 MB/s eta 0:00:02
#    -------- ------------------------------- 9.8/43.9 MB 19.6 MB/s eta 0:00:02
#    --------- ------------------------------ 10.6/43.9 MB 19.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.6/43.9 MB 19.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 12.5/43.9 MB 19.3 MB/s eta 0:00:02
#    ------------ --------------------------- 13.4/43.9 MB 19.8 MB/s eta 0:00:02
#    ------------- -------------------------- 14.3/43.9 MB 20.5 MB/s eta 0:00:02
#    ------------- -------------------------- 15.1/43.9 MB 19.9 MB/s eta 0:00:02
#    -------------- ------------------------- 15.5/43.9 MB 19.2 MB/s eta 0:00:02
#    --------------- ------------------------ 16.8/43.9 MB 19.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.6/43.9 MB 19.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.7/43.9 MB 20.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 19.5/43.9 MB 20.5 MB/s eta 0:00:02
#    ------------------ --------------------- 20.3/43.9 MB 20.5 MB/s eta 0:00:02
#    ------------------- -------------------- 21.1/43.9 MB 21.1 MB/s eta 0:00:02
#    -------------------- ------------------- 22.0/43.9 MB 20.5 MB/s eta 0:00:02
#    -------------------- ------------------- 22.9/43.9 MB 20.5 MB/s eta 0:00:02
#    --------------------- ------------------ 23.9/43.9 MB 20.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 24.6/43.9 MB 19.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 25.4/43.9 MB 21.1 MB/s eta 0:00:01
#    ------------------------ --------------- 26.4/43.9 MB 20.5 MB/s eta 0:00:01
#    ------------------------ --------------- 27.2/43.9 MB 20.5 MB/s eta 0:00:01
#    ------------------------- -------------- 28.0/43.9 MB 20.5 MB/s eta 0:00:01
#    -------------------------- ------------- 28.7/43.9 MB 20.5 MB/s eta 0:00:01
#    -------------------------- ------------- 29.5/43.9 MB 20.5 MB/s eta 0:00:01
#    --------------------------- ------------ 30.2/43.9 MB 19.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 30.9/43.9 MB 19.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 31.7/43.9 MB 19.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.5/43.9 MB 19.8 MB/s eta 0:00:01
#    ------------------------------ --------- 33.3/43.9 MB 19.8 MB/s eta 0:00:01
#    ------------------------------- -------- 34.0/43.9 MB 19.2 MB/s eta 0:00:01
#    ------------------------------- -------- 34.8/43.9 MB 19.8 MB/s eta 0:00:01
#    -------------------------------- ------- 35.6/43.9 MB 19.2 MB/s eta 0:00:01
#    --------------------------------- ------ 36.4/43.9 MB 18.7 MB/s eta 0:00:01
#    --------------------------------- ------ 37.3/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.1/43.9 MB 18.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 38.9/43.9 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------ --- 39.6/43.9 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------ --- 40.5/43.9 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/43.9 MB 18.7 MB/s eta 0:00:01
#    -------------------------------------- - 42.1/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  42.9/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  43.7/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  43.9/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  43.9/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  43.9/43.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 43.9/43.9 MB 15.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.8 kB ? eta -:--:--
#    --------------------------------------- 346.8/346.8 kB 22.4 MB/s eta 0:00:00
# Downloading virtualenv-20.29.1-py3-none-any.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.3 MB 26.8 MB/s eta 0:00:01
#    -------- ------------------------------- 0.9/4.3 MB 14.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.7/4.3 MB 15.5 MB/s eta 0:00:01
#    ------------------------ --------------- 2.6/4.3 MB 16.5 MB/s eta 0:00:01
#    -------------------------------- ------- 3.5/4.3 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------  4.3/4.3 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 15.2 MB/s eta 0:00:00
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.8 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.8 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.8 kB ? eta -:--:--
#    ---------------------------------------- 139.8/139.8 kB 1.0 MB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.3.5-py3-none-any.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.9/11.7 MB 30.1 MB/s eta 0:00:01
#    ------ --------------------------------- 2.0/11.7 MB 25.7 MB/s eta 0:00:01
#    --------- ------------------------------ 2.9/11.7 MB 22.8 MB/s eta 0:00:01
#    ------------ --------------------------- 3.6/11.7 MB 23.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.7 MB 22.3 MB/s eta 0:00:01
#    ------------------ --------------------- 5.5/11.7 MB 21.9 MB/s eta 0:00:01
#    --------------------- ------------------ 6.4/11.7 MB 21.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.4/11.7 MB 22.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.7 MB 21.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.7 MB 21.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.4/11.7 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.7 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  11.7/11.7 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  11.7/11.7 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 18.2 MB/s eta 0:00:00
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#    ---------------------------------------- 0.0/258.5 kB ? eta -:--:--
#    --------------------------------------- 258.5/258.5 kB 15.5 MB/s eta 0:00:00
# Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.9/13.2 MB 30.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.9/13.2 MB 29.9 MB/s eta 0:00:01
#    -------- ------------------------------- 2.7/13.2 MB 24.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.6/13.2 MB 23.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/13.2 MB 22.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.5/13.2 MB 22.1 MB/s eta 0:00:01
#    ------------------- -------------------- 6.4/13.2 MB 21.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/13.2 MB 22.2 MB/s eta 0:00:01
#    ------------------------- -------------- 8.3/13.2 MB 22.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/13.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------------ --------- 10.1/13.2 MB 21.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.9/13.2 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.9/13.2 MB 21.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 18.2 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.4 kB ? eta -:--:--
#    --------------------------------------- 163.4/163.4 kB 10.2 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ---------------------------------------- 0.0/469.0 kB ? eta -:--:--
#    --------------------------------------  460.8/469.0 kB 30.0 MB/s eta 0:00:01
#    --------------------------------------- 469.0/469.0 kB 14.8 MB/s eta 0:00:00
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 4.6 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.6 kB ? eta -:--:--
#    ---------------------------------------- 134.6/134.6 kB 7.8 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ---------------------------------------- 0.0/69.1 kB ? eta -:--:--
#    ---------------------------------------- 69.1/69.1 kB 3.7 MB/s eta 0:00:00
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#    ---------------------------------------- 0.0/385.8 kB ? eta -:--:--
#    --------------------------------------- 385.8/385.8 kB 12.1 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#    ---------------------------------------- 59.7/59.7 kB 3.1 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.4 kB ? eta -:--:--
#    --------------------------------------- 214.4/214.4 kB 12.8 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading mistune-3.1.1-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.7 kB ? eta -:--:--
#    ---------------------------------------- 53.7/53.7 kB 2.7 MB/s eta 0:00:00
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.1/2.3 MB 34.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 18.6 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#    ---------------------------------------- 0.0/186.0 kB ? eta -:--:--
#    ---------------------------------------- 186.0/186.0 kB 5.7 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.0 kB ? eta -:--:--
#    ---------------------------------------- 96.0/96.0 kB 5.7 MB/s eta 0:00:00
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.2 MB 20.7 MB/s eta 0:00:01
#    ------- -------------------------------- 1.9/10.2 MB 24.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.9/10.2 MB 22.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.8/10.2 MB 22.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.6/10.2 MB 21.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.4/10.2 MB 21.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.2/10.2 MB 21.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.2 MB 21.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.2 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.8/10.2 MB 20.9 MB/s eta 0:00:01
#    ------------------------------------- -- 9.6/10.2 MB 21.2 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.2 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.2 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 18.6 MB/s eta 0:00:00
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB 3.8 MB/s eta 0:00:00
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.5 kB ? eta -:--:--
#    ---------------------------------------- 88.5/88.5 kB 5.2 MB/s eta 0:00:00
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.7 kB ? eta -:--:--
#    ---------------------------------------- 54.7/54.7 kB 2.8 MB/s eta 0:00:00
# Downloading pywinpty-2.0.15-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------------- ---------- 1.0/1.4 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 12.7 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    ---------------------------------------- 166.4/166.4 kB 9.8 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#    ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.2 kB ? eta -:--:--
#    ---------------------------------------- 63.2/63.2 kB 3.3 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 5.8 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.22.3-cp311-cp311-win_amd64.whl (231 kB)
#    ---------------------------------------- 0.0/231.8 kB ? eta -:--:--
#    ---------------------------------------- 231.8/231.8 kB 7.1 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ---------------------------------------- 128.4/128.4 kB 7.4 MB/s eta 0:00:00
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    ---------------------------------------- 181.4/181.4 kB 5.5 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ---------------------------------------- 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB 7.2 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, distlib, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, tinycss2, threadpoolctl, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pyparsing, pyflakes, pycparser, pycodestyle, prometheus-client, pluggy, pillow, pandocfilters, overrides, numpy, nodeenv, mistune, mccabe, markupsafe, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, joblib, iniconfig, idna, identify, h11, fqdn, fonttools, filelock, defusedxml, cycler, charset-normalizer, cfgv, certifi, bleach, babel, attrs, async-lru, virtualenv, terminado, scipy, requests, referencing, pytest, pandas, jinja2, httpcore, flake8, contourpy, cffi, beautifulsoup4, arrow, anyio, scikit-learn, pre-commit, matplotlib, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, seaborn, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, funpymodeling
# Successfully installed anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-25.1.0 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 certifi-2025.1.31 cffi-1.17.1 cfgv-3.4.0 charset-normalizer-3.4.1 contourpy-1.3.1 cycler-0.12.1 defusedxml-0.7.1 distlib-0.3.9 fastjsonschema-2.21.1 filelock-3.17.0 flake8-6.1.0 fonttools-4.56.0 fqdn-1.5.1 funpymodeling-0.1.9 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 identify-2.6.7 idna-3.10 iniconfig-2.0.0 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.5 joblib-1.4.2 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 kiwisolver-1.4.8 markupsafe-3.0.2 matplotlib-3.10.0 mccabe-0.7.0 mistune-3.1.1 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 nodeenv-1.9.1 notebook-7.3.2 notebook-shim-0.2.4 numpy-1.26.4 overrides-7.7.0 pandas-2.2.3 pandocfilters-1.5.1 pillow-11.1.0 pluggy-1.5.0 pre-commit-3.8.0 prometheus-client-0.21.1 pycodestyle-2.11.1 pycparser-2.22 pyflakes-3.1.0 pyparsing-3.2.1 pytest-7.4.4 python-json-logger-3.2.1 pytz-2025.1 pywinpty-2.0.15 pyyaml-6.0.2 referencing-0.36.2 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.22.3 scikit-learn-1.6.1 scipy-1.15.1 seaborn-0.12.2 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 threadpoolctl-3.5.0 tinycss2-1.4.0 types-python-dateutil-2.9.0.20241206 tzdata-2025.1 uri-template-1.3.0 urllib3-2.3.0 virtualenv-20.29.1 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13
#   WARNING: The script wsdump.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script send2trash.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyflakes.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pycodestyle.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nodeenv.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyjson5.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script identify-cli.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script virtualenv.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts py.test.exe and pytest.exe are installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flake8.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pre-commit.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu.exe and jupyter-nbconvert.exe are installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jlpm.exe, jupyter-lab.exe, jupyter-labextension.exe and jupyter-labhub.exe are installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-notebook.exe is installed in 'c:\Users\valer\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from funpymodeling.exploratory import freq_tbl
import matplotlib.pyplot as plt

# %%
#Carga de mi archivo sin índice
df= pd.read_csv('Mexico_limpio.csv')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26582 non-null  int64
#  1   listing_url                                   26582 non-null  object
#  2   name                                          26582 non-null  object
#  3   description                                   26582 non-null  object
#  4   neighborhood_overview                         26582 non-null  object
#  5   picture_url                                   26582 non-null  object
#  6   host_name                                     26582 non-null  object
#  7   host_since                                    26582 non-null  object
#  8   host_response_time                            26582 non-null  object
#  9   host_response_rate                            26582 non-null  object
#  10  host_is_superhost                             26582 non-null  object
#  11  host_identity_verified                        26582 non-null  object
#  12  neighbourhood                                 26582 non-null  object
#  13  neighbourhood_cleansed                        26582 non-null  object
#  14  property_type                                 26582 non-null  object
#  15  room_type                                     26582 non-null  object
#  16  bathrooms_text                                26582 non-null  object
#  17  amenities                                     26582 non-null  object
#  18  has_availability                              26582 non-null  object
#  19  first_review                                  26582 non-null  object
#  20  last_review                                   26582 non-null  object
#  21  instant_bookable                              26582 non-null  object
#  22  id                                            26582 non-null  int64
#  23  latitude                                      26582 non-null  float64
#  24  longitude                                     26582 non-null  float64
#  25  accommodates                                  26582 non-null  float64
#  26  bathrooms                                     26582 non-null  float64
#  27  bedrooms                                      26582 non-null  float64
#  28  beds                                          26582 non-null  float64
#  29  price                                         26582 non-null  float64
#  30  minimum_nights                                26582 non-null  float64
#  31  maximum_nights                                26582 non-null  int64
#  32  availability_30                               26582 non-null  int64
#  33  availability_60                               26582 non-null  int64
#  34  availability_90                               26582 non-null  int64
#  35  availability_365                              26582 non-null  int64
#  36  number_of_reviews                             26582 non-null  float64
#  37  number_of_reviews_ltm                         26582 non-null  float64
#  38  number_of_reviews_l30d                        26582 non-null  float64
#  39  review_scores_rating                          26582 non-null  float64
#  40  review_scores_accuracy                        26582 non-null  float64
#  41  review_scores_cleanliness                     26582 non-null  float64
#  42  review_scores_checkin                         26582 non-null  float64
#  43  review_scores_communication                   26582 non-null  float64
#  44  review_scores_location                        26582 non-null  float64
#  45  review_scores_value                           26582 non-null  float64
#  46  calculated_host_listings_count                26582 non-null  float64
#  47  calculated_host_listings_count_entire_homes   26582 non-null  float64
#  48  calculated_host_listings_count_private_rooms  26582 non-null  float64
#  49  calculated_host_listings_count_shared_rooms   26582 non-null  float64
#  50  reviews_per_month                             26582 non-null  float64
# dtypes: float64(23), int64(7), object(21)
# memory usage: 10.3+ MB

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/35797          1
# 1       https://www.airbnb.com/rooms/897363738676670896          1
# 2       https://www.airbnb.com/rooms/897393613987324079          1
# 3       https://www.airbnb.com/rooms/894989092198576906          1
# 4       https://www.airbnb.com/rooms/894977949284306624          1
# ...                                                 ...        ...
# 26577             https://www.airbnb.com/rooms/47124933          1
# 26578             https://www.airbnb.com/rooms/47123755          1
# 26579             https://www.airbnb.com/rooms/47036712          1
# 26580             https://www.airbnb.com/rooms/47035738          1
# 26581  https://www.airbnb.com/rooms/1252229157495978163          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000075
# 2        0.000038         0.000113
# 3        0.000038         0.000150
# 4        0.000038         0.000188
# ...           ...              ...
# 26577    0.000038         0.999850
# 26578    0.000038         0.999887
# 26579    0.000038         0.999925
# 26580    0.000038         0.999962
# 26581    0.000038         1.000000
#
# [26582 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0         Blueground | Roma Sur 1 recamara, AC & rooftop         57
# 1                          Blueground | Polanco, parking         49
# 2                        Perfecto Loft en gran ubicación         48
# 3      Blueground | Amueblado, Security & Business Ce...         36
# 4                                       Magenta by Kukun         21
# ...                                                  ...        ...
# 25165      Astonishing view@Condesa best nbh perfect apt          1
# 25166  Private suite in Condesa Great internet & loca...          1
# 25167          Artsy habitación frente al Parque México!          1
# 25168  LOFT 14 (Parque Delta, Hosp. siglo XXI, Foro Sol)          1
# 25169                   Pretty, well centered, amenities          1
#
#        percentage  cumulative_perc
# 0        0.002144         0.002144
# 1        0.001843         0.003988
# 2        0.001806         0.005793
# 3        0.001354         0.007148
# 4        0.000790         0.007938
# ...           ...              ...
# 25165    0.000038         0.999850
# 25166    0.000038         0.999887
# 25167    0.000038         0.999925
# 25168    0.000038         0.999962
# 25169    0.000038         1.000000
#
# [25170 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              description  frequency  \
# 0                          No se proporciona descripción        933
# 1      Enjoy the simplicity of this quiet, central home.        106
# 2      This place has a strategic location - it will ...         65
# 3      If you are looking for an ideal accommodation ...         59
# 4      The loft is equipped to provide the utmost com...         53
# ...                                                  ...        ...
# 21623  Casa El Ángel has a great location! We are 1 b...          1
# 21624  Enjoy your stay in this carefully designed, su...          1
# 21625  Our space is located in a quiet, safe area and...          1
# 21626  Style and confortable furniture all over the p...          1
# 21627  Known as New Polanco, the Granada colony has p...          1
#
#        percentage  cumulative_perc
# 0        0.035099         0.035099
# 1        0.003988         0.039087
# 2        0.002445         0.041532
# 3        0.002220         0.043751
# 4        0.001994         0.045745
# ...           ...              ...
# 21623    0.000038         0.999850
# 21624    0.000038         0.999887
# 21625    0.000038         0.999925
# 21626    0.000038         0.999962
# 21627    0.000038         1.000000
#
# [21628 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                    neighborhood_overview  frequency  \
# 0                            No se proporcionan detalles      10895
# 1      Cuauhtémoc is located just west of the city ce...         98
# 2      High-end, urbane Polanco is one of the most so...         67
# 3      Located just south of trendy Roma Norte, famil...         60
# 4      You will find yourself in one of the best area...         47
# ...                                                  ...        ...
# 11540       Safe fractionation with 24-hour surveillance          1
# 11541  A block away is a park, several malls, cafes, ...          1
# 11542  Its located in a typical neighborhood in Mexic...          1
# 11543                            15 mins from this faith          1
# 11544  Welcome to Lomas de Bezares, a neighborhood kn...          1
#
#        percentage  cumulative_perc
# 0        0.409864         0.409864
# 1        0.003687         0.413551
# 2        0.002521         0.416071
# 3        0.002257         0.418328
# 4        0.001768         0.420096
# ...           ...              ...
# 11540    0.000038         0.999850
# 11541    0.000038         0.999887
# 11542    0.000038         0.999925
# 11543    0.000038         0.999962
# 11544    0.000038         1.000000
#
# [11545 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...         18
# 1      https://a0.muscache.com/pictures/miso/Hosting-...         14
# 2      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 3      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 4      https://a0.muscache.com/pictures/hosting/Hosti...         11
# ...                                                  ...        ...
# 25713  https://a0.muscache.com/pictures/4d9f6c9a-cd03...          1
# 25714  https://a0.muscache.com/pictures/b2a8f11c-6fce...          1
# 25715  https://a0.muscache.com/pictures/5774636b-1ed1...          1
# 25716  https://a0.muscache.com/pictures/41f89c21-6e42...          1
# 25717  https://a0.muscache.com/pictures/hosting/Hosti...          1
#
#        percentage  cumulative_perc
# 0        0.000677         0.000677
# 1        0.000527         0.001204
# 2        0.000451         0.001655
# 3        0.000451         0.002107
# 4        0.000414         0.002521
# ...           ...              ...
# 25713    0.000038         0.999850
# 25714    0.000038         0.999887
# 25715    0.000038         0.999925
# 25716    0.000038         0.999962
# 25717    0.000038         1.000000
#
# [25718 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#        host_name  frequency  percentage  cumulative_perc
# 0      Alejandra        341    0.012828         0.012828
# 1      Alejandro        293    0.011022         0.023851
# 2           Luis        292    0.010985         0.034836
# 3        Virtual        287    0.010797         0.045632
# 4     Blueground        258    0.009706         0.055338
# ...          ...        ...         ...              ...
# 4093   Ana Noemy          1    0.000038         0.999850
# 4094        Elié          1    0.000038         0.999887
# 4095         Cle          1    0.000038         0.999925
# 4096         Aby          1    0.000038         0.999962
# 4097       Yenny          1    0.000038         1.000000
#
# [4098 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     2023-01-30        267    0.010044         0.010044
# 1     2013-12-22        216    0.008126         0.018170
# 2     2020-02-02        177    0.006659         0.024829
# 3     2023-09-28        174    0.006546         0.031375
# 4     2016-04-27        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  2015-05-24          1    0.000038         0.999850
# 4046  2019-01-13          1    0.000038         0.999887
# 4047  2022-03-31          1    0.000038         0.999925
# 4048  2014-06-05          1    0.000038         0.999962
# 4049  2011-08-25          1    0.000038         1.000000
#
# [4050 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18792    0.706945         0.706945
# 1         Desconocido       3622    0.136258         0.843202
# 2  within a few hours       1957    0.073621         0.916823
# 3  a few days or more       1108    0.041682         0.958506
# 4        within a day       1103    0.041494         1.000000
#
# ----------------------------------------------------------------
#
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%      17583    0.661463         0.661463
# 1                  -%       3622    0.136258         0.797720
# 2                 99%       1106    0.041607         0.839327
# 3                  0%        567    0.021330         0.860658
# 4                 90%        559    0.021029         0.881687
# ..                ...        ...         ...              ...
# 72                18%          2    0.000075         0.999850
# 73                72%          1    0.000038         0.999887
# 74                46%          1    0.000038         0.999925
# 75                54%          1    0.000038         0.999962
# 76                 5%          1    0.000038         1.000000
#
# [77 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      16268    0.611993         0.611993
# 1                 t      10314    0.388007         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      25426    0.956512         0.956512
# 1                      f       1156    0.043488         1.000000
#
# ----------------------------------------------------------------
#
#                                          neighbourhood  frequency  percentage  \
# 0                Mexico City, Ciudad de México, Mexico      13066    0.491536
# 1                                  Mexico City, Mexico      11067    0.416334
# 2                            Mexico City, CDMX, Mexico        584    0.021970
# 3                Mexico City, Distrito Federal, Mexico        463    0.017418
# 4                     Centro, Ciudad de México, Mexico        227    0.008540
# ..                                                 ...        ...         ...
# 338                       Colonia Juárez, CDMX, Mexico          1    0.000038
# 339        Mexico City, Alcaldia Benito Juarez, Mexico          1    0.000038
# 340  Mexico City, Villa Coyoacan, Alcaldia Coyoacan...          1    0.000038
# 341           Alvaro Obregon, Ciudad de México, Mexico          1    0.000038
# 342  Centro Histórico de Ciudad de México, Ciudad d...          1    0.000038
#
#      cumulative_perc
# 0           0.491536
# 1           0.907870
# 2           0.929840
# 3           0.947258
# 4           0.955797
# ..               ...
# 338         0.999850
# 339         0.999887
# 340         0.999925
# 341         0.999962
# 342         1.000000
#
# [343 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#     neighbourhood_cleansed  frequency  percentage  cumulative_perc
# 0               Cuauhtémoc      12231    0.460123         0.460123
# 1           Miguel Hidalgo       4533    0.170529         0.630652
# 2            Benito Juárez       3152    0.118576         0.749229
# 3                 Coyoacán       1719    0.064668         0.813897
# 4           Álvaro Obregón       1075    0.040441         0.854338
# 5                  Tlalpan        812    0.030547         0.884885
# 6      Venustiano Carranza        734    0.027613         0.912497
# 7        Gustavo A. Madero        506    0.019035         0.931533
# 8    Cuajimalpa de Morelos        442    0.016628         0.948160
# 9                Iztacalco        399    0.015010         0.963171
# 10            Azcapotzalco        349    0.013129         0.976300
# 11              Iztapalapa        266    0.010007         0.986307
# 12  La Magdalena Contreras        143    0.005380         0.991686
# 13              Xochimilco        143    0.005380         0.997066
# 14                 Tláhuac         50    0.001881         0.998947
# 15              Milpa Alta         28    0.001053         1.000000
#
# ----------------------------------------------------------------
#
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9971    0.375103         0.375103
# 1                  Entire condo       3423    0.128771         0.503875
# 2   Private room in rental unit       3034    0.114137         0.618012
# 3          Private room in home       2266    0.085246         0.703258
# 4                   Entire loft       1515    0.056993         0.760251
# ..                          ...        ...         ...              ...
# 87        Private room in floor          1    0.000038         0.999850
# 88                 Earthen home          1    0.000038         0.999887
# 89                Entire in-law          1    0.000038         0.999925
# 90          Shared room in dorm          1    0.000038         0.999962
# 91                        Tower          1    0.000038         1.000000
#
# [92 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath      11309    0.425438         0.425438
# 1             2 baths       4611    0.173463         0.598902
# 2      1 private bath       3148    0.118426         0.717328
# 3       1 shared bath       2484    0.093447         0.810774
# 4           1.5 baths       1434    0.053946         0.864720
# 5           2.5 baths        856    0.032202         0.896923
# 6             3 baths        546    0.020540         0.917463
# 7    1.5 shared baths        460    0.017305         0.934768
# 8      2 shared baths        321    0.012076         0.946844
# 9           3.5 baths        250    0.009405         0.956249
# 10            4 baths        186    0.006997         0.963246
# 11   2.5 shared baths        121    0.004552         0.967798
# 12     3 shared baths        105    0.003950         0.971748
# 13          4.5 baths        102    0.003837         0.975585
# 14     4 shared baths         68    0.002558         0.978143
# 15            0 baths         55    0.002069         0.980212
# 16     5 shared baths         54    0.002031         0.982244
# 17            5 baths         51    0.001919         0.984162
# 18     0 shared baths         45    0.001693         0.985855
# 19            6 baths         44    0.001655         0.987510
# 20          Half-bath         41    0.001542         0.989053
# 21          5.5 baths         38    0.001430         0.990482
# 22   3.5 shared baths         33    0.001241         0.991724
# 23            7 baths         25    0.000940         0.992664
# 24   Shared half-bath         21    0.000790         0.993454
# 25   4.5 shared baths         20    0.000752         0.994207
# 26     6 shared baths         19    0.000715         0.994921
# 27            8 baths         18    0.000677         0.995599
# 28         11.5 baths         17    0.000640         0.996238
# 29          6.5 baths         14    0.000527         0.996765
# 30     8 shared baths         12    0.000451         0.997216
# 31  Private half-bath         10    0.000376         0.997592
# 32          7.5 baths         10    0.000376         0.997969
# 33            9 baths          8    0.000301         0.998270
# 34          8.5 baths          7    0.000263         0.998533
# 35           10 baths          5    0.000188         0.998721
# 36           11 baths          4    0.000150         0.998871
# 37           12 baths          3    0.000113         0.998984
# 38         12.5 baths          2    0.000075         0.999060
# 39           13 baths          2    0.000075         0.999135
# 40  11.5 shared baths          2    0.000075         0.999210
# 41           14 baths          2    0.000075         0.999285
# 42         10.5 baths          2    0.000075         0.999360
# 43    10 shared baths          2    0.000075         0.999436
# 44           16 baths          2    0.000075         0.999511
# 45    11 shared baths          1    0.000038         0.999549
# 46           21 baths          1    0.000038         0.999586
# 47           18 baths          1    0.000038         0.999624
# 48         14.5 baths          1    0.000038         0.999661
# 49           49 baths          1    0.000038         0.999699
# 50          9.5 baths          1    0.000038         0.999737
# 51    12 shared baths          1    0.000038         0.999774
# 52           17 baths          1    0.000038         0.999812
# 53    13 shared baths          1    0.000038         0.999850
# 54           15 baths          1    0.000038         0.999887
# 55           46 baths          1    0.000038         0.999925
# 56           20 baths          1    0.000038         0.999962
# 57           29 baths          1    0.000038         1.000000
#
# ----------------------------------------------------------------
#
#                                                amenities  frequency  \
# 0      ["Iron", "Elevator", "High chair", "Wifi", "Re...         71
# 1      ["Iron", "High chair", "Wifi", "Refrigerator",...         41
# 2                                                     []         40
# 3      ["Iron", "Wifi", "Heating", "Self check-in", "...         29
# 4      ["Iron", "Elevator", "High chair", "Wifi", "Re...         25
# ...                                                  ...        ...
# 24693  ["Host greets you", "Kitchen", "Refrigerator",...          1
# 24694  ["Iron", "Washer", "Private patio or balcony",...          1
# 24695  ["Iron", "Private patio or balcony", "Heating"...          1
# 24696  ["Shared patio or balcony", "Wifi", "Freezer",...          1
# 24697  ["Free parking on premises", "Washer", "TV", "...          1
#
#        percentage  cumulative_perc
# 0        0.002671         0.002671
# 1        0.001542         0.004213
# 2        0.001505         0.005718
# 3        0.001091         0.006809
# 4        0.000940         0.007750
# ...           ...              ...
# 24693    0.000038         0.999850
# 24694    0.000038         0.999887
# 24695    0.000038         0.999925
# 24696    0.000038         0.999962
# 24697    0.000038         1.000000
#
# [24698 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      26533    0.998157         0.998157
# 1                f         49    0.001843         1.000000
#
# ----------------------------------------------------------------
#
#      first_review  frequency  percentage  cumulative_perc
# 0      23/01/2025       3656    0.137537         0.137537
# 1      2023-08-27        105    0.003950         0.141487
# 2      2022-10-31        103    0.003875         0.145362
# 3      2023-10-29         82    0.003085         0.148446
# 4      2023-10-30         82    0.003085         0.151531
# ...           ...        ...         ...              ...
# 3321   2016-04-06          1    0.000038         0.999850
# 3322   2020-07-14          1    0.000038         0.999887
# 3323   2016-11-12          1    0.000038         0.999925
# 3324   2021-01-11          1    0.000038         0.999962
# 3325   2018-12-18          1    0.000038         1.000000
#
# [3326 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#      last_review  frequency  percentage  cumulative_perc
# 0     24/01/2025       3656    0.137537         0.137537
# 1     2024-09-22       1081    0.040667         0.178203
# 2     2024-09-16       1068    0.040178         0.218381
# 3     2024-09-23        898    0.033782         0.252163
# 4     2024-09-17        711    0.026747         0.278911
# ...          ...        ...         ...              ...
# 1630  2019-04-24          1    0.000038         0.999850
# 1631  2021-08-09          1    0.000038         0.999887
# 1632  2019-10-02          1    0.000038         0.999925
# 1633  2018-07-15          1    0.000038         0.999962
# 1634  2023-11-14          1    0.000038         1.000000
#
# [1635 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# **PASO 3. Extraer características a partir de aplicar un análisis univariado, a diferentes variables categóricas.**

# %%
#Obtengo análisis univariado de una variable categórica en específico
table1=freq_tbl(df['listing_url'])
table1
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/35797          1
# 1       https://www.airbnb.com/rooms/897363738676670896          1
# 2       https://www.airbnb.com/rooms/897393613987324079          1
# 3       https://www.airbnb.com/rooms/894989092198576906          1
# 4       https://www.airbnb.com/rooms/894977949284306624          1
# ...                                                 ...        ...
# 26577             https://www.airbnb.com/rooms/47124933          1
# 26578             https://www.airbnb.com/rooms/47123755          1
# 26579             https://www.airbnb.com/rooms/47036712          1
# 26580             https://www.airbnb.com/rooms/47035738          1
# 26581  https://www.airbnb.com/rooms/1252229157495978163          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000075
# 2        0.000038         0.000113
# 3        0.000038         0.000150
# 4        0.000038         0.000188
# ...           ...              ...
# 26577    0.000038         0.999850
# 26578    0.000038         0.999887
# 26579    0.000038         0.999925
# 26580    0.000038         0.999962
# 26581    0.000038         1.000000
#
# [26582 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table2=freq_tbl(df['name'])
table2
# Out:
#                                                     name  frequency  \
# 0         Blueground | Roma Sur 1 recamara, AC & rooftop         57
# 1                          Blueground | Polanco, parking         49
# 2                        Perfecto Loft en gran ubicación         48
# 3      Blueground | Amueblado, Security & Business Ce...         36
# 4                                       Magenta by Kukun         21
# ...                                                  ...        ...
# 25165      Astonishing view@Condesa best nbh perfect apt          1
# 25166  Private suite in Condesa Great internet & loca...          1
# 25167          Artsy habitación frente al Parque México!          1
# 25168  LOFT 14 (Parque Delta, Hosp. siglo XXI, Foro Sol)          1
# 25169                   Pretty, well centered, amenities          1
#
#        percentage  cumulative_perc
# 0        0.002144         0.002144
# 1        0.001843         0.003988
# 2        0.001806         0.005793
# 3        0.001354         0.007148
# 4        0.000790         0.007938
# ...           ...              ...
# 25165    0.000038         0.999850
# 25166    0.000038         0.999887
# 25167    0.000038         0.999925
# 25168    0.000038         0.999962
# 25169    0.000038         1.000000
#
# [25170 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table3=freq_tbl(df['description'])
table3
# Out:
#                                              description  frequency  \
# 0                          No se proporciona descripción        933
# 1      Enjoy the simplicity of this quiet, central home.        106
# 2      This place has a strategic location - it will ...         65
# 3      If you are looking for an ideal accommodation ...         59
# 4      The loft is equipped to provide the utmost com...         53
# ...                                                  ...        ...
# 21623  Casa El Ángel has a great location! We are 1 b...          1
# 21624  Enjoy your stay in this carefully designed, su...          1
# 21625  Our space is located in a quiet, safe area and...          1
# 21626  Style and confortable furniture all over the p...          1
# 21627  Known as New Polanco, the Granada colony has p...          1
#
#        percentage  cumulative_perc
# 0        0.035099         0.035099
# 1        0.003988         0.039087
# 2        0.002445         0.041532
# 3        0.002220         0.043751
# 4        0.001994         0.045745
# ...           ...              ...
# 21623    0.000038         0.999850
# 21624    0.000038         0.999887
# 21625    0.000038         0.999925
# 21626    0.000038         0.999962
# 21627    0.000038         1.000000
#
# [21628 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table4=freq_tbl(df['neighborhood_overview'])
table4
# Out:
#                                    neighborhood_overview  frequency  \
# 0                            No se proporcionan detalles      10895
# 1      Cuauhtémoc is located just west of the city ce...         98
# 2      High-end, urbane Polanco is one of the most so...         67
# 3      Located just south of trendy Roma Norte, famil...         60
# 4      You will find yourself in one of the best area...         47
# ...                                                  ...        ...
# 11540       Safe fractionation with 24-hour surveillance          1
# 11541  A block away is a park, several malls, cafes, ...          1
# 11542  Its located in a typical neighborhood in Mexic...          1
# 11543                            15 mins from this faith          1
# 11544  Welcome to Lomas de Bezares, a neighborhood kn...          1
#
#        percentage  cumulative_perc
# 0        0.409864         0.409864
# 1        0.003687         0.413551
# 2        0.002521         0.416071
# 3        0.002257         0.418328
# 4        0.001768         0.420096
# ...           ...              ...
# 11540    0.000038         0.999850
# 11541    0.000038         0.999887
# 11542    0.000038         0.999925
# 11543    0.000038         0.999962
# 11544    0.000038         1.000000
#
# [11545 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table5=freq_tbl(df['picture_url'])
table5
# Out:
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...         18
# 1      https://a0.muscache.com/pictures/miso/Hosting-...         14
# 2      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 3      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 4      https://a0.muscache.com/pictures/hosting/Hosti...         11
# ...                                                  ...        ...
# 25713  https://a0.muscache.com/pictures/4d9f6c9a-cd03...          1
# 25714  https://a0.muscache.com/pictures/b2a8f11c-6fce...          1
# 25715  https://a0.muscache.com/pictures/5774636b-1ed1...          1
# 25716  https://a0.muscache.com/pictures/41f89c21-6e42...          1
# 25717  https://a0.muscache.com/pictures/hosting/Hosti...          1
#
#        percentage  cumulative_perc
# 0        0.000677         0.000677
# 1        0.000527         0.001204
# 2        0.000451         0.001655
# 3        0.000451         0.002107
# 4        0.000414         0.002521
# ...           ...              ...
# 25713    0.000038         0.999850
# 25714    0.000038         0.999887
# 25715    0.000038         0.999925
# 25716    0.000038         0.999962
# 25717    0.000038         1.000000
#
# [25718 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table6=freq_tbl(df['host_name'])
table6
# Out:
#        host_name  frequency  percentage  cumulative_perc
# 0      Alejandra        341    0.012828         0.012828
# 1      Alejandro        293    0.011022         0.023851
# 2           Luis        292    0.010985         0.034836
# 3        Virtual        287    0.010797         0.045632
# 4     Blueground        258    0.009706         0.055338
# ...          ...        ...         ...              ...
# 4093   Ana Noemy          1    0.000038         0.999850
# 4094        Elié          1    0.000038         0.999887
# 4095         Cle          1    0.000038         0.999925
# 4096         Aby          1    0.000038         0.999962
# 4097       Yenny          1    0.000038         1.000000
#
# [4098 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table7=freq_tbl(df['host_since'])
table7
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     2023-01-30        267    0.010044         0.010044
# 1     2013-12-22        216    0.008126         0.018170
# 2     2020-02-02        177    0.006659         0.024829
# 3     2023-09-28        174    0.006546         0.031375
# 4     2016-04-27        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  2015-05-24          1    0.000038         0.999850
# 4046  2019-01-13          1    0.000038         0.999887
# 4047  2022-03-31          1    0.000038         0.999925
# 4048  2014-06-05          1    0.000038         0.999962
# 4049  2011-08-25          1    0.000038         1.000000
#
# [4050 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table8=freq_tbl(df['host_response_time'])
table8
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18792    0.706945         0.706945
# 1         Desconocido       3622    0.136258         0.843202
# 2  within a few hours       1957    0.073621         0.916823
# 3  a few days or more       1108    0.041682         0.958506
# 4        within a day       1103    0.041494         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table9=freq_tbl(df['host_response_rate'])
table9
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%      17583    0.661463         0.661463
# 1                  -%       3622    0.136258         0.797720
# 2                 99%       1106    0.041607         0.839327
# 3                  0%        567    0.021330         0.860658
# 4                 90%        559    0.021029         0.881687
# ..                ...        ...         ...              ...
# 72                18%          2    0.000075         0.999850
# 73                72%          1    0.000038         0.999887
# 74                46%          1    0.000038         0.999925
# 75                54%          1    0.000038         0.999962
# 76                 5%          1    0.000038         1.000000
#
# [77 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table10=freq_tbl(df['host_is_superhost'])
table10
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      16268    0.611993         0.611993
# 1                 t      10314    0.388007         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table11=freq_tbl(df['host_identity_verified'])
table11
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      25426    0.956512         0.956512
# 1                      f       1156    0.043488         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table12=freq_tbl(df['neighbourhood'])
table12
# Out:
#                                          neighbourhood  frequency  percentage  \
# 0                Mexico City, Ciudad de México, Mexico      13066    0.491536
# 1                                  Mexico City, Mexico      11067    0.416334
# 2                            Mexico City, CDMX, Mexico        584    0.021970
# 3                Mexico City, Distrito Federal, Mexico        463    0.017418
# 4                     Centro, Ciudad de México, Mexico        227    0.008540
# ..                                                 ...        ...         ...
# 338                       Colonia Juárez, CDMX, Mexico          1    0.000038
# 339        Mexico City, Alcaldia Benito Juarez, Mexico          1    0.000038
# 340  Mexico City, Villa Coyoacan, Alcaldia Coyoacan...          1    0.000038
# 341           Alvaro Obregon, Ciudad de México, Mexico          1    0.000038
# 342  Centro Histórico de Ciudad de México, Ciudad d...          1    0.000038
#
#      cumulative_perc
# 0           0.491536
# 1           0.907870
# 2           0.929840
# 3           0.947258
# 4           0.955797
# ..               ...
# 338         0.999850
# 339         0.999887
# 340         0.999925
# 341         0.999962
# 342         1.000000
#
# [343 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table13=freq_tbl(df['neighbourhood_cleansed'])
table13
# Out:
#     neighbourhood_cleansed  frequency  percentage  cumulative_perc
# 0               Cuauhtémoc      12231    0.460123         0.460123
# 1           Miguel Hidalgo       4533    0.170529         0.630652
# 2            Benito Juárez       3152    0.118576         0.749229
# 3                 Coyoacán       1719    0.064668         0.813897
# 4           Álvaro Obregón       1075    0.040441         0.854338
# 5                  Tlalpan        812    0.030547         0.884885
# 6      Venustiano Carranza        734    0.027613         0.912497
# 7        Gustavo A. Madero        506    0.019035         0.931533
# 8    Cuajimalpa de Morelos        442    0.016628         0.948160
# 9                Iztacalco        399    0.015010         0.963171
# 10            Azcapotzalco        349    0.013129         0.976300
# 11              Iztapalapa        266    0.010007         0.986307
# 12  La Magdalena Contreras        143    0.005380         0.991686
# 13              Xochimilco        143    0.005380         0.997066
# 14                 Tláhuac         50    0.001881         0.998947
# 15              Milpa Alta         28    0.001053         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table14=freq_tbl(df['property_type'])
table14
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9971    0.375103         0.375103
# 1                  Entire condo       3423    0.128771         0.503875
# 2   Private room in rental unit       3034    0.114137         0.618012
# 3          Private room in home       2266    0.085246         0.703258
# 4                   Entire loft       1515    0.056993         0.760251
# ..                          ...        ...         ...              ...
# 87        Private room in floor          1    0.000038         0.999850
# 88                 Earthen home          1    0.000038         0.999887
# 89                Entire in-law          1    0.000038         0.999925
# 90          Shared room in dorm          1    0.000038         0.999962
# 91                        Tower          1    0.000038         1.000000
#
# [92 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table15=freq_tbl(df['room_type'])
table15
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table16=freq_tbl(df['bathrooms_text'])
table16
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath      11309    0.425438         0.425438
# 1             2 baths       4611    0.173463         0.598902
# 2      1 private bath       3148    0.118426         0.717328
# 3       1 shared bath       2484    0.093447         0.810774
# 4           1.5 baths       1434    0.053946         0.864720
# 5           2.5 baths        856    0.032202         0.896923
# 6             3 baths        546    0.020540         0.917463
# 7    1.5 shared baths        460    0.017305         0.934768
# 8      2 shared baths        321    0.012076         0.946844
# 9           3.5 baths        250    0.009405         0.956249
# 10            4 baths        186    0.006997         0.963246
# 11   2.5 shared baths        121    0.004552         0.967798
# 12     3 shared baths        105    0.003950         0.971748
# 13          4.5 baths        102    0.003837         0.975585
# 14     4 shared baths         68    0.002558         0.978143
# 15            0 baths         55    0.002069         0.980212
# 16     5 shared baths         54    0.002031         0.982244
# 17            5 baths         51    0.001919         0.984162
# 18     0 shared baths         45    0.001693         0.985855
# 19            6 baths         44    0.001655         0.987510
# 20          Half-bath         41    0.001542         0.989053
# 21          5.5 baths         38    0.001430         0.990482
# 22   3.5 shared baths         33    0.001241         0.991724
# 23            7 baths         25    0.000940         0.992664
# 24   Shared half-bath         21    0.000790         0.993454
# 25   4.5 shared baths         20    0.000752         0.994207
# 26     6 shared baths         19    0.000715         0.994921
# 27            8 baths         18    0.000677         0.995599
# 28         11.5 baths         17    0.000640         0.996238
# 29          6.5 baths         14    0.000527         0.996765
# 30     8 shared baths         12    0.000451         0.997216
# 31  Private half-bath         10    0.000376         0.997592
# 32          7.5 baths         10    0.000376         0.997969
# 33            9 baths          8    0.000301         0.998270
# 34          8.5 baths          7    0.000263         0.998533
# 35           10 baths          5    0.000188         0.998721
# 36           11 baths          4    0.000150         0.998871
# 37           12 baths          3    0.000113         0.998984
# 38         12.5 baths          2    0.000075         0.999060
# 39           13 baths          2    0.000075         0.999135
# 40  11.5 shared baths          2    0.000075         0.999210
# 41           14 baths          2    0.000075         0.999285
# 42         10.5 baths          2    0.000075         0.999360
# 43    10 shared baths          2    0.000075         0.999436
# 44           16 baths          2    0.000075         0.999511
# 45    11 shared baths          1    0.000038         0.999549
# 46           21 baths          1    0.000038         0.999586
# 47           18 baths          1    0.000038         0.999624
# 48         14.5 baths          1    0.000038         0.999661
# 49           49 baths          1    0.000038         0.999699
# 50          9.5 baths          1    0.000038         0.999737
# 51    12 shared baths          1    0.000038         0.999774
# 52           17 baths          1    0.000038         0.999812
# 53    13 shared baths          1    0.000038         0.999850
# 54           15 baths          1    0.000038         0.999887
# 55           46 baths          1    0.000038         0.999925
# 56           20 baths          1    0.000038         0.999962
# 57           29 baths          1    0.000038         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table17=freq_tbl(df['amenities'])
table17
# Out:
#                                                amenities  frequency  \
# 0      ["Iron", "Elevator", "High chair", "Wifi", "Re...         71
# 1      ["Iron", "High chair", "Wifi", "Refrigerator",...         41
# 2                                                     []         40
# 3      ["Iron", "Wifi", "Heating", "Self check-in", "...         29
# 4      ["Iron", "Elevator", "High chair", "Wifi", "Re...         25
# ...                                                  ...        ...
# 24693  ["Host greets you", "Kitchen", "Refrigerator",...          1
# 24694  ["Iron", "Washer", "Private patio or balcony",...          1
# 24695  ["Iron", "Private patio or balcony", "Heating"...          1
# 24696  ["Shared patio or balcony", "Wifi", "Freezer",...          1
# 24697  ["Free parking on premises", "Washer", "TV", "...          1
#
#        percentage  cumulative_perc
# 0        0.002671         0.002671
# 1        0.001542         0.004213
# 2        0.001505         0.005718
# 3        0.001091         0.006809
# 4        0.000940         0.007750
# ...           ...              ...
# 24693    0.000038         0.999850
# 24694    0.000038         0.999887
# 24695    0.000038         0.999925
# 24696    0.000038         0.999962
# 24697    0.000038         1.000000
#
# [24698 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table18=freq_tbl(df['has_availability'])
table18
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      26533    0.998157         0.998157
# 1                f         49    0.001843         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table19=freq_tbl(df['first_review'])
table19
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0      23/01/2025       3656    0.137537         0.137537
# 1      2023-08-27        105    0.003950         0.141487
# 2      2022-10-31        103    0.003875         0.145362
# 3      2023-10-29         82    0.003085         0.148446
# 4      2023-10-30         82    0.003085         0.151531
# ...           ...        ...         ...              ...
# 3321   2016-04-06          1    0.000038         0.999850
# 3322   2020-07-14          1    0.000038         0.999887
# 3323   2016-11-12          1    0.000038         0.999925
# 3324   2021-01-11          1    0.000038         0.999962
# 3325   2018-12-18          1    0.000038         1.000000
#
# [3326 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table20=freq_tbl(df['last_review'])
table20
# Out:
#      last_review  frequency  percentage  cumulative_perc
# 0     24/01/2025       3656    0.137537         0.137537
# 1     2024-09-22       1081    0.040667         0.178203
# 2     2024-09-16       1068    0.040178         0.218381
# 3     2024-09-23        898    0.033782         0.252163
# 4     2024-09-17        711    0.026747         0.278911
# ...          ...        ...         ...              ...
# 1630  2019-04-24          1    0.000038         0.999850
# 1631  2021-08-09          1    0.000038         0.999887
# 1632  2019-10-02          1    0.000038         0.999925
# 1633  2018-07-15          1    0.000038         0.999962
# 1634  2023-11-14          1    0.000038         1.000000
#
# [1635 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table21=freq_tbl(df['instant_bookable'])
table21
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table1_2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
table1_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f1= table1_2[table1_2['frequency']>0]
f1
#Ajusto el índice de mi dataframe
F1_index= f1.set_index('listing_url')
F1_index
# Out:
#                                                   frequency
# listing_url
# https://www.airbnb.com/rooms/35797                        1
# https://www.airbnb.com/rooms/897363738676670896           1
# https://www.airbnb.com/rooms/897393613987324079           1
# https://www.airbnb.com/rooms/894989092198576906           1
# https://www.airbnb.com/rooms/894977949284306624           1
# ...                                                     ...
# https://www.airbnb.com/rooms/47124933                     1
# https://www.airbnb.com/rooms/47123755                     1
# https://www.airbnb.com/rooms/47036712                     1
# https://www.airbnb.com/rooms/47035738                     1
# https://www.airbnb.com/rooms/1252229157495978163          1
#
# [26582 rows x 1 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table1.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table2_2= table2.drop(['percentage', 'cumulative_perc'], axis=1)
table2_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f2= table2_2[table2_2['frequency']>15]
f2
#Ajusto el índice de mi dataframe
F2_index= f2.set_index('name')
F2_index
# Out:
#                                                     frequency
# name
# Blueground | Roma Sur 1 recamara, AC & rooftop             57
# Blueground | Polanco, parking                              49
# Perfecto Loft en gran ubicación                            48
# Blueground | Amueblado, Security & Business Center         36
# Magenta by Kukun                                           21
# Casa Miravalle | Condesa                                   21
# Departamento 2 cuartos                                     20
# Single and shared rooms near downtown.                     20
# Blueground | Amueblado 2 recamaras, Security 24/7          19
# Blueground | Cuauhtémoc Business Center & Terrace          18
# Departamento en Ciudad de México                           16

# %%
#Realizamos grafico de barras del dataframe filtrado
F2_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Nombre')
plt.xlabel('Tipo de Nombres')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table3_2= table3.drop(['percentage', 'cumulative_perc'], axis=1)
table3_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f3= table3_2[table3_2['frequency']>50]
f3
#Ajusto el índice de mi dataframe
F3_index= f3.set_index('description')
F3_index
# Out:
#                                                     frequency
# description
# No se proporciona descripción                             933
# Enjoy the simplicity of this quiet, central home.         106
# This place has a strategic location - it will b...         65
# If you are looking for an ideal accommodation f...         59
# The loft is equipped to provide the utmost comf...         53

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table3.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table4_2= table4.drop(['percentage', 'cumulative_perc'], axis=1)
table4_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f4= table4_2[table4_2['frequency']>40]
f4
#Ajusto el índice de mi dataframe
F4_index= f4.set_index('neighborhood_overview')
F4_index
# Out:
#                                                     frequency
# neighborhood_overview
# No se proporcionan detalles                             10895
# Cuauhtémoc is located just west of the city cen...         98
# High-end, urbane Polanco is one of the most sou...         67
# Located just south of trendy Roma Norte, family...         60
# You will find yourself in one of the best areas...         47
# Enjoy Roma Norte a top neighborhood in Mexico C...         46

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table4.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table5_2= table5.drop(['percentage', 'cumulative_perc'], axis=1)
table5_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f5= table5_2[table5_2['frequency']>7]
f5
#Ajusto el índice de mi dataframe
F5_index= f5.set_index('picture_url')
F5_index
# Out:
#                                                     frequency
# picture_url
# https://a0.muscache.com/pictures/miso/Hosting-8...         18
# https://a0.muscache.com/pictures/miso/Hosting-8...         14
# https://a0.muscache.com/pictures/miso/Hosting-1...         12
# https://a0.muscache.com/pictures/miso/Hosting-7...         12
# https://a0.muscache.com/pictures/hosting/Hostin...         11
# https://a0.muscache.com/pictures/39cb839e-71fe-...         10
# https://a0.muscache.com/pictures/84510e1f-072c-...          9
# https://a0.muscache.com/pictures/e2c41d52-a2b8-...          9
# https://a0.muscache.com/pictures/eb5bf4ee-db18-...          9
# https://a0.muscache.com/pictures/miso/Hosting-6...          9
# https://a0.muscache.com/pictures/5c6c08cd-b049-...          8
# https://a0.muscache.com/pictures/miso/Hosting-8...          8
# https://a0.muscache.com/pictures/3189c695-cf94-...          8

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table5.plot("frequency","cumulative_perc", kind= "scatter",color= "darkblue")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table6_2= table6.drop(['percentage', 'cumulative_perc'], axis=1)
table6_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f6= table6_2[table6_2['frequency']>200]
f6
#Ajusto el índice de mi dataframe
F6_index= f6.set_index('host_name')
F6_index
# Out:
#             frequency
# host_name
# Alejandra         341
# Alejandro         293
# Luis              292
# Virtual           287
# Blueground        258
# Mr. W             243
# Juan              239
# Jorge             223
# Carlos            222

# %%
#Realizamos grafico de área del dataframe filtrado
F6_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "purple")
# Out:
# <Axes: xlabel='host_name'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table7_2= table7.drop(['percentage', 'cumulative_perc'], axis=1)
table7_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f7= table7_2[table7_2['frequency']>100]
f7
#Ajusto el índice de mi dataframe
F7_index= f7.set_index('host_since')
F7_index
# Out:
#             frequency
# host_since
# 2023-01-30        267
# 2013-12-22        216
# 2020-02-02        177
# 2023-09-28        174
# 2016-04-27        156
# 2018-08-04        129
# 2023-01-26        127
# 2019-02-26        116
# 2016-08-22        115
# 2014-11-07        107
# 2019-10-15        101

# %%
#Realizamos grafico de barras del dataframe filtrado
F7_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Antigüedad del anfitrión')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table8_2= table8.drop(['percentage', 'cumulative_perc'], axis=1)
table8_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f8= table8_2[table8_2['frequency']>0]
f8
#Ajusto el índice de mi dataframe
F8_index= f8.set_index('host_response_time')
F8_index
# Out:
#                     frequency
# host_response_time
# within an hour          18792
# Desconocido              3622
# within a few hours       1957
# a few days or more       1108
# within a day             1103

# %%
#Realizamos grafico de barras del dataframe filtrado
F8_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Tiempo que tarda un anfitrión ')
plt.xlabel('Tiempos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table9_2= table9.drop(['percentage', 'cumulative_perc'], axis=1)
table9_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f9= table9_2[table9_2['frequency']>180]
f9
#Ajusto el índice de mi dataframe
F9_index= f9.set_index('host_response_rate')
F9_index
# Out:
#                     frequency
# host_response_rate
# 100%                    17583
# -%                       3622
# 99%                      1106
# 0%                        567
# 90%                       559
# 98%                       262
# 80%                       234
# 97%                       222
# 96%                       194

# %%
#Realizamos grafico de área del dataframe filtrado
F9_index.plot(kind='area', figsize=(15,4),alpha= 0.5, color= "darkblue")
# Out:
# <Axes: xlabel='host_response_rate'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table10_2= table10.drop(['percentage', 'cumulative_perc'], axis=1)
table10_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f10= table10_2[table10_2['frequency']>100]
f10
#Ajusto el índice de mi dataframe
F10_index= f10.set_index('host_is_superhost')
F10_index
# Out:
#                    frequency
# host_is_superhost
# f                      16268
# t                      10314

# %%
#Realizamos grafico de pastel del dataframe filtrado
F10_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table11_2= table11.drop(['percentage', 'cumulative_perc'], axis=1)
table11_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f11= table11_2[table11_2['frequency']>1000]
f11
#Ajusto el índice de mi dataframe
F11_index= f11.set_index('host_identity_verified')
F11_index
# Out:
#                         frequency
# host_identity_verified
# t                           25426
# f                            1156

# %%
#Realizamos grafico de pastel del dataframe filtrado
F11_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table12_2= table12.drop(['percentage', 'cumulative_perc'], axis=1)
table12_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f12= table12_2[table12_2['frequency']>100]
f12
#Ajusto el índice de mi dataframe
F12_index= f12.set_index('neighbourhood')
F12_index
# Out:
#                                        frequency
# neighbourhood
# Mexico City, Ciudad de México, Mexico      13066
# Mexico City, Mexico                        11067
# Mexico City, CDMX, Mexico                    584
# Mexico City, Distrito Federal, Mexico        463
# Centro, Ciudad de México, Mexico             227
# Mexico City, Federal District, Mexico        183
# Juárez, Ciudad de México, Mexico             166

# %%
#Realizamos grafico de barras del dataframe filtrado
F12_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Vecindario ')
plt.xlabel('Nombres de Vecindarios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table13_2= table13.drop(['percentage', 'cumulative_perc'], axis=1)
table13_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f13= table13_2[table13_2['frequency']>300]
f13
#Ajusto el índice de mi dataframe
F13_index= f13.set_index('neighbourhood_cleansed')
F13_index
# Out:
#                         frequency
# neighbourhood_cleansed
# Cuauhtémoc                  12231
# Miguel Hidalgo               4533
# Benito Juárez                3152
# Coyoacán                     1719
# Álvaro Obregón               1075
# Tlalpan                       812
# Venustiano Carranza           734
# Gustavo A. Madero             506
# Cuajimalpa de Morelos         442
# Iztacalco                     399
# Azcapotzalco                  349

# %%
#Realizamos grafico de barras del dataframe filtrado
F13_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Vecindario Nombres Limpios ')
plt.xlabel('Nombres de Vecindarios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table14_2= table14.drop(['percentage', 'cumulative_perc'], axis=1)
table14_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f14= table14_2[table14_2['frequency']>500]
f14
#Ajusto el índice de mi dataframe
F14_index= f14.set_index('property_type')
F14_index
# Out:
#                              frequency
# property_type
# Entire rental unit                9971
# Entire condo                      3423
# Private room in rental unit       3034
# Private room in home              2266
# Entire loft                       1515
# Private room in condo              846
# Entire serviced apartment          846
# Entire home                        817
# Room in hotel                      504

# %%
#Realizamos grafico de barras del dataframe filtrado
F14_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Propiedades ')
plt.xlabel('Tipos de Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table15_2= table15.drop(['percentage', 'cumulative_perc'], axis=1)
table15_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f15= table15_2[table15_2['frequency']>0]
f15
#Ajusto el índice de mi dataframe
F15_index= f15.set_index('room_type')
F15_index
# Out:
#                  frequency
# room_type
# Entire home/apt      17363
# Private room          8693
# Shared room            401
# Hotel room             125

# %%
#Realizamos grafico de barras del dataframe filtrado
F15_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Recámaras')
plt.xlabel('Tipos de Recámaras')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table16_2= table16.drop(['percentage', 'cumulative_perc'], axis=1)
table16_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f16= table16_2[table16_2['frequency']>300]
f16
#Ajusto el índice de mi dataframe
F16_index= f16.set_index('bathrooms_text')
F16_index
# Out:
#                   frequency
# bathrooms_text
# 1 bath                11309
# 2 baths                4611
# 1 private bath         3148
# 1 shared bath          2484
# 1.5 baths              1434
# 2.5 baths               856
# 3 baths                 546
# 1.5 shared baths        460
# 2 shared baths          321

# %%
#Realizamos grafico de pastel del dataframe filtrado
F16_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table17_2= table17.drop(['percentage', 'cumulative_perc'], axis=1)
table17_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f17= table17_2[table17_2['frequency']>18]
f17
#Ajusto el índice de mi dataframe
F17_index= f17.set_index('amenities')
F17_index
# Out:
#                                                     frequency
# amenities
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         71
# ["Iron", "High chair", "Wifi", "Refrigerator", ...         41
# []                                                         40
# ["Iron", "Wifi", "Heating", "Self check-in", "H...         29
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         25
# ["TV", "Wifi", "Kitchen"]                                  24
# ["Washer", "TV", "Wifi", "Kitchen", "Dedicated ...         23
# ["Iron", "Wifi", "Refrigerator", "Self check-in...         20

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table17.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table18_2= table18.drop(['percentage', 'cumulative_perc'], axis=1)
table18_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f18= table18_2[table18_2['frequency']>0]
f18
#Ajusto el índice de mi dataframe
F18_index= f18.set_index('has_availability')
F18_index
# Out:
#                   frequency
# has_availability
# t                     26533
# f                        49

# %%
#Realizamos grafico de pastel del dataframe filtrado
F18_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table19_2= table19.drop(['percentage', 'cumulative_perc'], axis=1)
table19_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f19= table19_2[table19_2['frequency']>80]
f19
#Ajusto el índice de mi dataframe
F19_index= f19.set_index('first_review')
F19_index
# Out:
#               frequency
# first_review
# 23/01/2025         3656
# 2023-08-27          105
# 2022-10-31          103
# 2023-10-29           82
# 2023-10-30           82

# %%
#Realizamos grafico de pastel del dataframe filtrado
F19_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table20_2= table20.drop(['percentage', 'cumulative_perc'], axis=1)
table20_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f20= table20_2[table20_2['frequency']>450]
f10
#Ajusto el índice de mi dataframe
F20_index= f20.set_index('last_review')
F20_index
# Out:
#              frequency
# last_review
# 24/01/2025        3656
# 2024-09-22        1081
# 2024-09-16        1068
# 2024-09-23         898
# 2024-09-17         711
# 2024-09-08         680
# 2024-09-01         537
# 2024-09-21         513

# %%
#Realizamos grafico de pastel del dataframe filtrado
F20_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table21_2= table21.drop(['percentage', 'cumulative_perc'], axis=1)
table21_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f21= table21_2[table21_2['frequency']>0]
f21
#Ajusto el índice de mi dataframe
F21_index= f21.set_index('instant_bookable')
F21_index
# Out:
#                   frequency
# instant_bookable
# f                     16080
# t                     10502

# %%
#Realizamos grafico de pastel del dataframe filtrado
F21_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **PASO 4. Categorizar las siguientes variable**

# %% [markdown]
# **Determinación de clases para datos agrupados**

# %%
#Calculamos el numero total de la poblacion "n"
#df['accommodates'].info()
n=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max= df['accommodates'].max()
Min= df['accommodates'].min()
Limites=[Min, Max]
Limites
#Calcular el Rango R
R= Max-Min
R
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i= R/ni
i
# Out:
# 0.38241817134564404

# %%
#Calculamos el numero total de la poblacion "n"
df['beds'].info()
n2=26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
#Obtenemos el límite superior e inferior de la columna objetivo
Max2= df['beds'].max()
Min2= df['beds'].min()
Limites2= [Min2,Max2]
Limites2
# Out:
# [0.0, 3.0]

# %%
#Calcular el Rango R
R2= Max2-Min2
R2
# Out:
# 3.0

# %%
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni2= 1+3.32*np.log10(n2)
ni2
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i2= R2/ni2
i2
# Out:
# 0.19120908567282202

# %%
#Calculamos el numero total de la poblacion "n"
#df['price'].info()
n3=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max3= df['price'].max()
Min3= df['price'].min()
Limites3=[Min3, Max3]
Limites3
#Calcular el Rango R
R3= Max3-Min3
R3
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni3= 1+3.32*np.log10(n3)
ni3
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i3= R3/ni3
i3
# Out:
# 178.0156587613973

# %%
#Calculamos el numero total de la poblacion "n"
#df['availability_365'].info()
n4=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max4= df['availability_365'].max()
Min4= df['availability_365'].min()
Limites4=[Min4, Max4]
Limites4
#Calcular el Rango R
R4= Max4-Min4
R4
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni4= 1+3.32*np.log10(n4)
ni4
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i4= R4/ni4
i4
# Out:
# 23.263772090193346

# %%
#Calculamos el numero total de la poblacion "n"
#df['number_of_reviews'].info()
n5=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max5= df['number_of_reviews'].max()
Min5= df['number_of_reviews'].min()
Limites5=[Min5, Max5]
Limites5
#Calcular el Rango R
R5= Max5-Min5
R5
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni5= 1+3.32*np.log10(n5)
ni5
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i5= R5/ni5
i5
# Out:
# 8.60440885527699

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_location'].info()
n6=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max6= df['review_scores_location'].max()
Min6= df['review_scores_location'].min()
Limites6=[Min6, Max6]
Limites6
#Calcular el Rango R
R6= Max6-Min6
R6
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni6= 1+3.32*np.log10(n6)
ni6
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i6= R6/ni6
i6
# Out:
# 0.03186818094547034

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_value'].info()
n7=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max7= df['review_scores_value'].max()
Min7= df['review_scores_value'].min()
Limites7=[Min7, Max7]
Limites7
#Calcular el Rango R
R7= Max7-Min7
R7
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni7= 1+3.32*np.log10(n7)
ni7
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i7= R7/ni7
i7
# Out:
# 0.03951654437238322

# %%
#Calculamos el numero total de la poblacion "n"
#df['reviews_scores_communication'].info()
n8=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max8= df['review_scores_communication'].max()
Min8= df['review_scores_communication'].min()
Limites8=[Min8, Max8]
Limites8
#Calcular el Rango R
R8= Max8-Min8
R8
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni8= 1+3.32*np.log10(n8)
ni8
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i8= R8/ni8
i8
# Out:
# 0.026769271994195078

# %%
#Calculamos el numero total de la poblacion "n"
#df['reviews_per_month'].info()
n9=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max9= df['reviews_per_month'].max()
Min9= df['reviews_per_month'].min()
Limites9=[Min9, Max9]
Limites9
#Calcular el Rango R
R9= Max9-Min9
R9
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni9= 1+3.32*np.log10(n9)
ni9
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i9= R9/ni9
i9
# Out:
# 0.3001982645063306

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_checkin'].info()
n10=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max10= df['review_scores_checkin'].max()
Min10= df['review_scores_checkin'].min()
Limites10=[Min10, Max10]
Limites10
#Calcular el Rango R
R10= Max10-Min10
R10
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni10= 1+3.32*np.log10(n10)
ni10
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i10= R10/ni10
i10
# Out:
# 0.025494544756376292

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_accuracy'].info()
n11=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max11= df['review_scores_accuracy'].max()
Min11= df['review_scores_accuracy'].min()
Limites11=[Min11, Max11]
Limites11
#Calcular el Rango R
R11= Max11-Min11
R11
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni11= 1+3.32*np.log10(n11)
ni11
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i11= R11/ni11
i11
# Out:
# 0.030593453707651548

# %% [markdown]
# **Creación de categorias/intervalos**

# %%
#Categorización de variables
intervalos=np.linspace(Min,Max,16)
intervalos
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. , 5.4, 5.8,
#        6.2, 6.6, 7. ])

# %%
#Creamos las categorías
categorias= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['accommodates']= pd.cut(x=df['accommodates'],bins=intervalos,labels=categorias)
df['accommodates']
# Out:
# 0        Categoria3
# 1        Categoria5
# 2        Categoria8
# 3        Categoria3
# 4        Categoria3
#             ...
# 26577    Categoria8
# 26578    Categoria3
# 26579    Categoria3
# 26580    Categoria3
# 26581    Categoria3
# Name: accommodates, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos2=np.linspace(Min2,Max2,16)
intervalos2
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. ])

# %%
#Creamos las categorías
categorias2= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['beds']= pd.cut(x=df['beds'],bins=intervalos2,labels=categorias2)
df['beds']
# Out:
# 0          Categoria5
# 1          Categoria5
# 2        Categorias10
# 3          Categoria5
# 4          Categoria5
#              ...
# 26577    Categorias10
# 26578      Categoria5
# 26579      Categoria5
# 26580      Categoria5
# 26581      Categoria5
# Name: beds, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos3=np.linspace(Min3,Max3,16)
intervalos3
# Out:
# array([   0. ,  186.2,  372.4,  558.6,  744.8,  931. , 1117.2, 1303.4,
#        1489.6, 1675.8, 1862. , 2048.2, 2234.4, 2420.6, 2606.8, 2793. ])

# %%
#Creamos las categorías
categorias3= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['price']= pd.cut(x=df['price'],bins=intervalos3,labels=categorias3)
df['price']
# Out:
# 0          Categoria6
# 1         Categorias9
# 2        Categorias11
# 3          Categoria7
# 4          Categoria6
#              ...
# 26577      Categoria3
# 26578      Categoria6
# 26579    Categorias15
# 26580    Categorias14
# 26581      Categoria8
# Name: price, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos4=np.linspace(Min4,Max4,16)
intervalos4
# Out:
# array([  0.        ,  24.33333333,  48.66666667,  73.        ,
#         97.33333333, 121.66666667, 146.        , 170.33333333,
#        194.66666667, 219.        , 243.33333333, 267.66666667,
#        292.        , 316.33333333, 340.66666667, 365.        ])

# %%
#Creamos las categorías
categorias4= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['availability_365']= pd.cut(x=df['availability_365'],bins=intervalos4,labels=categorias4)
df['availability_365']
# Out:
# 0        Categoria15
# 1        Categoria14
# 2        Categoria14
# 3        Categoria11
# 4        Categoria12
#             ...
# 26577    Categoria15
# 26578     Categoria8
# 26579     Categoria8
# 26580     Categoria8
# 26581     Categoria7
# Name: availability_365, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos5=np.linspace(Min5,Max5,16)
intervalos5
# Out:
# array([  0.,   9.,  18.,  27.,  36.,  45.,  54.,  63.,  72.,  81.,  90.,
#         99., 108., 117., 126., 135.])

# %%
#Creamos las categorías
categorias5= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['number_of_reviews']= pd.cut(x=df['number_of_reviews'],bins=intervalos5,labels=categorias5)
df['number_of_reviews']
# Out:
# 0                NaN
# 1         Categoria8
# 2         Categoria6
# 3        Categoria15
# 4         Categoria2
#             ...
# 26577            NaN
# 26578            NaN
# 26579            NaN
# 26580            NaN
# 26581            NaN
# Name: number_of_reviews, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos6=np.linspace(Min6,Max6,16)
intervalos6
# Out:
# array([4.5       , 4.53333333, 4.56666667, 4.6       , 4.63333333,
#        4.66666667, 4.7       , 4.73333333, 4.76666667, 4.8       ,
#        4.83333333, 4.86666667, 4.9       , 4.93333333, 4.96666667,
#        5.        ])

# %%
#Creamos las categorías
categorias6= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_location']= pd.cut(x=df['review_scores_location'],bins=intervalos6,labels=categorias6)
df['review_scores_location']
# Out:
# 0         Categoria9
# 1        Categoria15
# 2        Categoria15
# 3        Categoria14
# 4        Categoria13
#             ...
# 26577     Categoria9
# 26578     Categoria9
# 26579     Categoria9
# 26580     Categoria9
# 26581     Categoria9
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos7=np.linspace(Min7,Max7,16)
intervalos7
# Out:
# array([4.38      , 4.42133333, 4.46266667, 4.504     , 4.54533333,
#        4.58666667, 4.628     , 4.66933333, 4.71066667, 4.752     ,
#        4.79333333, 4.83466667, 4.876     , 4.91733333, 4.95866667,
#        5.        ])

# %%
#Creamos las categorías
categorias7= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_value']= pd.cut(x=df['review_scores_value'],bins=intervalos7,labels=categorias7)
df['review_scores_value']
# Out:
# 0         Categoria8
# 1         Categoria3
# 2        Categoria13
# 3        Categoria14
# 4        Categoria11
#             ...
# 26577     Categoria8
# 26578     Categoria8
# 26579     Categoria8
# 26580     Categoria8
# 26581     Categoria8
# Name: review_scores_value, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos8=np.linspace(Min8,Max8,16)
intervalos8
# Out:
# array([4.58 , 4.608, 4.636, 4.664, 4.692, 4.72 , 4.748, 4.776, 4.804,
#        4.832, 4.86 , 4.888, 4.916, 4.944, 4.972, 5.   ])

# %%
#Creamos las categorías
categorias8= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_communication']= pd.cut(x=df['review_scores_communication'],bins=intervalos8,labels=categorias8)
df['review_scores_communication']
# Out:
# 0        Categoria15
# 1         Categoria8
# 2        Categoria13
# 3        Categoria15
# 4         Categoria6
#             ...
# 26577    Categoria15
# 26578    Categoria15
# 26579    Categoria15
# 26580    Categoria15
# 26581    Categoria15
# Name: review_scores_communication, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos9=np.linspace(Min9,Max9,16)
intervalos9
# Out:
# array([0.01 , 0.324, 0.638, 0.952, 1.266, 1.58 , 1.894, 2.208, 2.522,
#        2.836, 3.15 , 3.464, 3.778, 4.092, 4.406, 4.72 ])

# %%
#Creamos las categorías
categorias9= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['reviews_per_month']= pd.cut(x=df['reviews_per_month'],bins=intervalos9,labels=categorias9)
df['reviews_per_month']
# Out:
# 0        Categoria6
# 1        Categoria2
# 2        Categoria1
# 3        Categoria3
# 4        Categoria1
#             ...
# 26577    Categoria6
# 26578    Categoria6
# 26579    Categoria6
# 26580    Categoria6
# 26581    Categoria6
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos10=np.linspace(Min10,Max10,16)
intervalos10
# Out:
# array([4.6       , 4.62666667, 4.65333333, 4.68      , 4.70666667,
#        4.73333333, 4.76      , 4.78666667, 4.81333333, 4.84      ,
#        4.86666667, 4.89333333, 4.92      , 4.94666667, 4.97333333,
#        5.        ])

# %%
#Creamos las categorías
categorias10= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_checkin']= pd.cut(x=df['review_scores_checkin'],bins=intervalos10,labels=categorias10)
df['review_scores_checkin']
# Out:
# 0        Categoria15
# 1        Categoria11
# 2        Categoria13
# 3        Categoria14
# 4        Categoria15
#             ...
# 26577    Categoria15
# 26578    Categoria15
# 26579    Categoria15
# 26580    Categoria15
# 26581    Categoria15
# Name: review_scores_checkin, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos11=np.linspace(Min11,Max11,16)
intervalos11
# Out:
# array([4.52 , 4.552, 4.584, 4.616, 4.648, 4.68 , 4.712, 4.744, 4.776,
#        4.808, 4.84 , 4.872, 4.904, 4.936, 4.968, 5.   ])

# %%
#Creamos las categorías
categorias11= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_accuracy']= pd.cut(x=df['review_scores_accuracy'],bins=intervalos11,labels=categorias11)
df['review_scores_accuracy']
# Out:
# 0         Categoria9
# 1         Categoria2
# 2        Categoria10
# 3        Categoria12
# 4        Categoria15
#             ...
# 26577     Categoria9
# 26578     Categoria9
# 26579     Categoria9
# 26580     Categoria9
# 26581     Categoria9
# Name: review_scores_accuracy, Length: 26582, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %% [markdown]
# **Creamos gráficas y tablas de las categoricas recién creadas**

# %%
#Obtego análidsis univariado de una variable categórica en específico
table22= freq_tbl(df['accommodates'])
table22
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table22_2= table22.drop(['percentage', 'cumulative_perc'], axis=1)
table22_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f22= table22_2[table22_2['frequency']>0]
f22
#Ajusto el índice de mi dataframe
F22_index= f22.set_index('accommodates')
F22_index
# Out:
#               frequency
# accommodates
# Categoria3        10620
# Categoria8         5690
# Categoria5         3753
# Categorias13       1800
# Categorias10       1375
# Categorias15        311

# %%
#Realizamos grafico de barras del dataframe filtrado
F22_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Máximo de Huespedes')
plt.xlabel('Cantidad de huespedes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table23= freq_tbl(df['beds'])
table23
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table23_2= table23.drop(['percentage', 'cumulative_perc'], axis=1)
table23_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f23= table23_2[table23_2['frequency']>0]
f23
#Ajusto el índice de mi dataframe
F23_index= f23.set_index('beds')
F23_index
# Out:
#               frequency
# beds
# Categoria5        14362
# Categorias10       6467
# Categorias15       2834
# Categoria8         2447

# %%
#Realizamos grafico de barras del dataframe filtrado
F23_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Camas')
plt.xlabel('Cantidad de camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table24= freq_tbl(df['price'])
table24
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table24_2= table24.drop(['percentage', 'cumulative_perc'], axis=1)
table24_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f24= table24_2[table24_2['frequency']>400]
f24
#Ajusto el índice de mi dataframe
F24_index= f24.set_index('price')
F24_index
# Out:
#               frequency
# price
# Categoria6         4792
# Categorias9        4191
# Categoria3         3107
# Categoria5         2975
# Categoria4         2741
# Categoria7         2119
# Categoria2         1910
# Categoria8         1395
# Categorias10        916
# Categorias11        847
# Categorias12        480

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table24.plot("frequency","cumulative_perc", kind= "scatter",color= "green")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table25= freq_tbl(df['availability_365'])
table25
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table25_2= table25.drop(['percentage', 'cumulative_perc'], axis=1)
table25_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f25= table25_2[table25_2['frequency']>800]
f25
#Ajusto el índice de mi dataframe
F25_index= f25.set_index('availability_365')
F25_index
# Out:
#                   frequency
# availability_365
# Categoria15            6605
# Categoria14            2815
# Categoria11            1977
# Categoria4             1692
# Categoria12            1570
# Categoria13            1436
# Categoria3             1236
# Categoria7             1122
# Categoria8             1089
# Categoria10            1052
# Categoria6              883

# %%
#Realizamos grafico de área del dataframe filtrado
F25_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "darkblue")
# Out:
# <Axes: xlabel='availability_365'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table26= freq_tbl(df['number_of_reviews'])
table26
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table26_2= table26.drop(['percentage', 'cumulative_perc'], axis=1)
table26_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f26= table26_2[table26_2['frequency']>500]
f26
#Ajusto el índice de mi dataframe
F26_index= f26.set_index('number_of_reviews')
F26_index
# Out:
#                    frequency
# number_of_reviews
# Categoria1              7242
# Categoria3              4353
# Categoria2              3017
# Categoria4              1573
# Categoria5              1239
# Categoria6               994
# Categoria7               880
# Categoria8               729
# Categoria9               581
# Categoria10              548

# %%
#Realizamos grafico de pastel del dataframe filtrado
F26_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table27= freq_tbl(df['review_scores_location'])
table27
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table27_2= table27.drop(['percentage', 'cumulative_perc'], axis=1)
table27_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f27= table27_2[table27_2['frequency']>700]
f27
#Ajusto el índice de mi dataframe
F27_index= f27.set_index('review_scores_location')
F27_index
# Out:
#                         frequency
# review_scores_location
# Categoria15                  8601
# Categoria9                   4757
# Categoria12                  3354
# Categoria14                  2370
# Categoria13                  1999
# Categoria11                  1131
# Categoria10                  1063
# Categoria6                    714

# %%
#Realizamos grafico de pastel del dataframe filtrado
F27_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table28= freq_tbl(df['review_scores_value'])
table28
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table28_2= table28.drop(['percentage', 'cumulative_perc'], axis=1)
table28_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f28= table28_2[table28_2['frequency']>800]
f28
#Ajusto el índice de mi dataframe
F28_index= f28.set_index('review_scores_value')
F28_index
# Out:
#                      frequency
# review_scores_value
# Categoria8                5524
# Categoria15               4664
# Categoria11               4111
# Categoria13               2051
# Categoria12               1913
# Categoria10               1683
# Categoria9                1544
# Categoria14               1465

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table28.plot("frequency","cumulative_perc", kind= "scatter",color= "green")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table29= freq_tbl(df['review_scores_communication'])
table29
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table29_2= table29.drop(['percentage', 'cumulative_perc'], axis=1)
table29_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f29= table29_2[table29_2['frequency']>800]
f29
#Ajusto el índice de mi dataframe
F29_index= f29.set_index('review_scores_communication')
F29_index
# Out:
#                              frequency
# review_scores_communication
# Categoria15                      11726
# Categoria12                       3884
# Categoria14                       2137
# Categoria13                       2050
# Categoria10                       1163
# Categoria9                        1079
# Categoria11                       1006
# Categoria8                         889

# %%
#Realizamos grafico de área del dataframe filtrado
F29_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "purple")
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table30= freq_tbl(df['reviews_per_month'])
table30
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table30_2= table30.drop(['percentage', 'cumulative_perc'], axis=1)
table30_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f30= table30_2[table30_2['frequency']>900]
f30
#Ajusto el índice de mi dataframe
F30_index= f30.set_index('reviews_per_month')
F30_index
# Out:
#                    frequency
# reviews_per_month
# Categoria6              4966
# Categoria1              4634
# Categoria5              3052
# Categoria2              2937
# Categoria3              2309
# Categoria4              2115
# Categoria7              1314
# Categoria8              1087

# %%
#Realizamos grafico de barras del dataframe filtrado
F30_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Reseñas por mes')
plt.xlabel('Reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table31= freq_tbl(df['review_scores_checkin'])
table31
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table31_2= table31.drop(['percentage', 'cumulative_perc'], axis=1)
table31_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f31= table31_2[table31_2['frequency']>500]
f31
#Ajusto el índice de mi dataframe
F31_index= f31.set_index('review_scores_checkin')
F31_index
# Out:
#                        frequency
# review_scores_checkin
# Categoria15                11293
# Categoria12                 3895
# Categoria14                 2136
# Categoria11                 1771
# Categoria13                 1554
# Categoria9                  1169
# Categoria8                   992
# Categoria10                  928
# Categoria6                   677

# %%
#Realizamos grafico de pastel del dataframe filtrado
F31_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table32= freq_tbl(df['review_scores_accuracy'])
table32
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table32_2= table32.drop(['percentage', 'cumulative_perc'], axis=1)
table32_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f32= table32_2[table32_2['frequency']>0]
f32
#Ajusto el índice de mi dataframe
F32_index= f32.set_index('review_scores_accuracy')
F32_index
# Out:
#                         frequency
# review_scores_accuracy
# Categoria15                  6369
# Categoria9                   4821
# Categoria12                  4260
# Categoria13                  1925
# Categoria10                  1785
# Categoria14                  1734
# Categoria11                  1475
# Categoria8                   1035
# Categoria5                    773
# Categoria7                    637
# Categoria6                    605
# Categoria4                    369
# Categoria3                    316
# Categoria2                    285
# Categoria1                    159

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table32.plot("frequency","cumulative_perc", kind= "scatter",color= "darkblue")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>
