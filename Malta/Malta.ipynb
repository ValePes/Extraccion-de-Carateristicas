# %%
#Instalamos 
# %pip install funpymodeling
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: funpymodeling in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (0.1.9)
# Requirement already satisfied: flake8<7.0.0,>=6.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (6.1.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (1.1.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (2.2.3)
# Requirement already satisfied: pre-commit<4.0.0,>=3.3.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (3.8.0)
# Requirement already satisfied: pytest<8.0.0,>=7.3.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (7.4.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (1.6.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from funpymodeling) (0.12.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.6.3 in c:\users\valer\appdata\roaming\python\python311\site-packages (from funpymodeling) (4.12.2)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (0.7.0)
# Requirement already satisfied: pycodestyle<2.12.0,>=2.11.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (2.11.1)
# Requirement already satisfied: pyflakes<3.2.0,>=3.1.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (3.1.0)
# Requirement already satisfied: notebook in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.3.2)
# Requirement already satisfied: jupyter-console in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (4.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\valer\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.1)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (2.6.7)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (20.29.1)
# Requirement already satisfied: iniconfig in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (1.5.0)
# Requirement already satisfied: colorama in c:\users\valer\appdata\roaming\python\python311\site-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (0.4.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\valer\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.17.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (4.3.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.6.0)
# Requirement already satisfied: psutil in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.50)
# Requirement already satisfied: pygments in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.19.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (65.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.4.0)
# Requirement already satisfied: anyio in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.8.0)
# Requirement already satisfied: certifi in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.0.7)
# Requirement already satisfied: idna in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.14.0)
# Requirement already satisfied: decorator in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\valer\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.6.3)
# Requirement already satisfied: pywin32>=300 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\valer\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\valer\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\valer\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\valer\appdata\local\programs\python\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.9.0.20241206)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from funpymodeling.exploratory import freq_tbl
import matplotlib.pyplot as plt

# %%
#Carga de mi archivo sin índice
df= pd.read_csv('Malta_limpio.csv')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12609 entries, 0 to 12608
# Data columns (total 53 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    12609 non-null  int64
#  1   listing_url                                   12609 non-null  object
#  2   name                                          12609 non-null  object
#  3   description                                   12609 non-null  object
#  4   neighborhood_overview                         12609 non-null  object
#  5   picture_url                                   12609 non-null  object
#  6   host_name                                     12609 non-null  object
#  7   host_since                                    12609 non-null  object
#  8   host_response_time                            12609 non-null  object
#  9   host_response_rate                            12609 non-null  object
#  10  host_is_superhost                             12609 non-null  object
#  11  host_identity_verified                        12609 non-null  object
#  12  neighbourhood                                 12609 non-null  object
#  13  property_type                                 12609 non-null  object
#  14  room_type                                     12609 non-null  object
#  15  bathrooms_text                                12609 non-null  object
#  16  amenities                                     12609 non-null  object
#  17  has_availability                              12609 non-null  object
#  18  availability_30                               12609 non-null  int64
#  19  first_review                                  12609 non-null  object
#  20  last_review                                   12609 non-null  object
#  21  review_scores_rating                          12609 non-null  float64
#  22  instant_bookable                              12609 non-null  object
#  23  region_id                                     12609 non-null  object
#  24  region_name                                   12609 non-null  object
#  25  id                                            12609 non-null  int64
#  26  latitude                                      12609 non-null  float64
#  27  longitude                                     12609 non-null  float64
#  28  accommodates                                  12609 non-null  float64
#  29  bathrooms                                     12609 non-null  float64
#  30  bedrooms                                      12609 non-null  float64
#  31  beds                                          12609 non-null  float64
#  32  price                                         12609 non-null  float64
#  33  minimum_nights                                12609 non-null  float64
#  34  maximum_nights                                12609 non-null  int64
#  35  availability_30.1                             12609 non-null  int64
#  36  availability_60                               12609 non-null  int64
#  37  availability_90                               12609 non-null  int64
#  38  availability_365                              12609 non-null  int64
#  39  number_of_reviews                             12609 non-null  float64
#  40  number_of_reviews_ltm                         12609 non-null  float64
#  41  number_of_reviews_l30d                        12609 non-null  float64
#  42  review_scores_accuracy                        12609 non-null  float64
#  43  review_scores_cleanliness                     12609 non-null  float64
#  44  review_scores_checkin                         12609 non-null  float64
#  45  review_scores_communication                   12609 non-null  float64
#  46  review_scores_location                        12609 non-null  float64
#  47  review_scores_value                           12609 non-null  float64
#  48  calculated_host_listings_count                12609 non-null  float64
#  49  calculated_host_listings_count_entire_homes   12609 non-null  float64
#  50  calculated_host_listings_count_private_rooms  12609 non-null  float64
#  51  calculated_host_listings_count_shared_rooms   12609 non-null  float64
#  52  reviews_per_month                             12609 non-null  float64
# dtypes: float64(23), int64(8), object(22)
# memory usage: 5.1+ MB

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/50188          1
# 1      https://www.airbnb.com/rooms/1029420514294269216          1
# 2      https://www.airbnb.com/rooms/1029520809475335209          1
# 3      https://www.airbnb.com/rooms/1029633246045276883          1
# 4      https://www.airbnb.com/rooms/1029791534903536257          1
# ...                                                 ...        ...
# 12604             https://www.airbnb.com/rooms/53931502          1
# 12605             https://www.airbnb.com/rooms/53945539          1
# 12606             https://www.airbnb.com/rooms/53946097          1
# 12607             https://www.airbnb.com/rooms/53946234          1
# 12608  https://www.airbnb.com/rooms/1250838221147721892          1
#
#        percentage  cumulative_perc
# 0        0.000079         0.000079
# 1        0.000079         0.000159
# 2        0.000079         0.000238
# 3        0.000079         0.000317
# 4        0.000079         0.000397
# ...           ...              ...
# 12604    0.000079         0.999683
# 12605    0.000079         0.999762
# 12606    0.000079         0.999841
# 12607    0.000079         0.999921
# 12608    0.000079         1.000000
#
# [12609 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0      1BR sensation, Fully equipped with In/Outdoor ...         25
# 1               Charming Room in Sliema Creek Guesthouse         21
# 2      St Julians, Indoor/Outdoor Pool, LUX ROOM & Views         17
# 3         Seafront, LUX Room with IN/OUTdoor pool heaven         16
# 4             Double Room/Studio in the Center of Sliema         13
# ...                                                  ...        ...
# 12068                           City Central Apartment 1          1
# 12069  Central Room ★ 5Mins to Valletta ★ Best Bus Ro...          1
# 12070                           City Central Apartment 2          1
# 12071                                     Pandora's loft          1
# 12072                       Luxury 3 rooms for 6 persons          1
#
#        percentage  cumulative_perc
# 0        0.001983         0.001983
# 1        0.001665         0.003648
# 2        0.001348         0.004996
# 3        0.001269         0.006265
# 4        0.001031         0.007296
# ...           ...              ...
# 12068    0.000079         0.999683
# 12069    0.000079         0.999762
# 12070    0.000079         0.999841
# 12071    0.000079         0.999921
# 12072    0.000079         1.000000
#
# [12073 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              description  frequency  \
# 0                          No se proporciona descripción        210
# 1      The whole group will enjoy easy access to ever...         73
# 2      Enjoy a stylish experience at this centrally-l...         43
# 3      Keep it simple at this peaceful and centrally-...         42
# 4      Your family will be close to everything when y...         36
# ...                                                  ...        ...
# 10368  Large 2 bedroom apartment, in the old part of ...          1
# 10369  Look no further, one of a KIND APT with probab...          1
# 10370  Experience the history of the Old City in an e...          1
# 10371  WE ARE A PROFESSIONAL PROPERTY MANAGEMENT COMP...          1
# 10372  These are 3 rooms on ground level, forming par...          1
#
#        percentage  cumulative_perc
# 0        0.016655         0.016655
# 1        0.005790         0.022444
# 2        0.003410         0.025855
# 3        0.003331         0.029186
# 4        0.002855         0.032041
# ...           ...              ...
# 10368    0.000079         0.999683
# 10369    0.000079         0.999762
# 10370    0.000079         0.999841
# 10371    0.000079         0.999921
# 10372    0.000079         1.000000
#
# [10373 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                   neighborhood_overview  frequency  \
# 0                           No se proporcionan detalles       6692
# 1     Sliema is a town located on the northeast coas...        128
# 2     This property is located in a quiet local neig...         58
# 3     The village of St. Julian’s (locally referred ...         42
# 4     St. Paul's is surrounded by breathtaking coast...         40
# ...                                                 ...        ...
# 4004  The property is located in the old town centre...          1
# 4005  Alvin’s home is located in Marsalforn, Island ...          1
# 4006  - Bugibba Square<br />- Shops/Bar/Restaurants ...          1
# 4007  The property is located in the center of Gharb...          1
# 4008  Renowned for its picturesque promenade, St Jul...          1
#
#       percentage  cumulative_perc
# 0       0.530732         0.530732
# 1       0.010151         0.540883
# 2       0.004600         0.545483
# 3       0.003331         0.548814
# 4       0.003172         0.551987
# ...          ...              ...
# 4004    0.000079         0.999683
# 4005    0.000079         0.999762
# 4006    0.000079         0.999841
# 4007    0.000079         0.999921
# 4008    0.000079         1.000000
#
# [4009 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/d3a0ac57-59f6...         16
# 1      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 2      https://a0.muscache.com/pictures/miso/Hosting-...         10
# 3      https://a0.muscache.com/pictures/hosting/Hosti...         10
# 4      https://a0.muscache.com/pictures/hosting/Hosti...          9
# ...                                                  ...        ...
# 12018  https://a0.muscache.com/pictures/miso/Hosting-...          1
# 12019  https://a0.muscache.com/pictures/4fd07f69-f5ef...          1
# 12020  https://a0.muscache.com/pictures/2ab79aee-9725...          1
# 12021  https://a0.muscache.com/pictures/miso/Hosting-...          1
# 12022  https://a0.muscache.com/pictures/hosting/Hosti...          1
#
#        percentage  cumulative_perc
# 0        0.001269         0.001269
# 1        0.000952         0.002221
# 2        0.000793         0.003014
# 3        0.000793         0.003807
# 4        0.000714         0.004521
# ...           ...              ...
# 12018    0.000079         0.999683
# 12019    0.000079         0.999762
# 12020    0.000079         0.999841
# 12021    0.000079         0.999921
# 12022    0.000079         1.000000
#
# [12023 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                        host_name  frequency  percentage  cumulative_perc
# 0     Matthew ThreeSixty Estates        540    0.042827         0.042827
# 1                          Aaron        197    0.015624         0.058450
# 2                         Andrea        146    0.011579         0.070029
# 3                         Joseph        117    0.009279         0.079308
# 4                         Zzzing        112    0.008883         0.088191
# ...                          ...        ...         ...              ...
# 2052                       Diego          1    0.000079         0.999683
# 2053                     Saviour          1    0.000079         0.999762
# 2054                  Anna Marie          1    0.000079         0.999841
# 2055                      Mayara          1    0.000079         0.999921
# 2056                    Кароліна          1    0.000079         1.000000
#
# [2057 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     2022-09-02        456    0.036165         0.036165
# 1     2012-05-23        190    0.015069         0.051233
# 2     2019-12-18        112    0.008883         0.060116
# 3     2017-02-28        110    0.008724         0.068840
# 4     2021-01-20        100    0.007931         0.076771
# ...          ...        ...         ...              ...
# 2663  2016-10-25          1    0.000079         0.999683
# 2664  2022-09-10          1    0.000079         0.999762
# 2665  2022-09-08          1    0.000079         0.999841
# 2666  2015-05-06          1    0.000079         0.999921
# 2667  2011-05-31          1    0.000079         1.000000
#
# [2668 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       9413    0.746530         0.746530
# 1         Desconocido       1278    0.101356         0.847886
# 2  within a few hours        943    0.074788         0.922674
# 3        within a day        643    0.050995         0.973670
# 4  a few days or more        332    0.026330         1.000000
#
# ----------------------------------------------------------------
#
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%       8410    0.666984         0.666984
# 1                  -%       1278    0.101356         0.768340
# 2                 95%        489    0.038782         0.807122
# 3                 98%        432    0.034261         0.841383
# 4                 90%        325    0.025775         0.867158
# 5                 99%        292    0.023158         0.890316
# 6                 97%        192    0.015227         0.905544
# 7                  0%        145    0.011500         0.917043
# 8                 80%        112    0.008883         0.925926
# 9                 75%         81    0.006424         0.932350
# 10                50%         71    0.005631         0.937981
# 11                10%         59    0.004679         0.942660
# 12                96%         56    0.004441         0.947101
# 13                93%         56    0.004441         0.951543
# 14                94%         49    0.003886         0.955429
# 15                20%         45    0.003569         0.958998
# 16                79%         44    0.003490         0.962487
# 17                88%         41    0.003252         0.965739
# 18                70%         40    0.003172         0.968911
# 19                92%         39    0.003093         0.972004
# 20                86%         39    0.003093         0.975097
# 21                67%         35    0.002776         0.977873
# 22                30%         34    0.002696         0.980569
# 23                83%         23    0.001824         0.982394
# 24                91%         22    0.001745         0.984138
# 25                56%         21    0.001665         0.985804
# 26                89%         20    0.001586         0.987390
# 27                60%         20    0.001586         0.988976
# 28                40%         13    0.001031         0.990007
# 29                87%         11    0.000872         0.990880
# 30                72%         10    0.000793         0.991673
# 31                85%          9    0.000714         0.992386
# 32                57%          8    0.000634         0.993021
# 33                13%          8    0.000634         0.993655
# 34                82%          8    0.000634         0.994290
# 35                65%          8    0.000634         0.994924
# 36                33%          7    0.000555         0.995479
# 37                78%          7    0.000555         0.996035
# 38                15%          6    0.000476         0.996510
# 39                77%          6    0.000476         0.996986
# 40                64%          6    0.000476         0.997462
# 41                71%          6    0.000476         0.997938
# 42                14%          4    0.000317         0.998255
# 43                73%          3    0.000238         0.998493
# 44                58%          3    0.000238         0.998731
# 45                25%          3    0.000238         0.998969
# 46                11%          3    0.000238         0.999207
# 47                81%          3    0.000238         0.999445
# 48                17%          2    0.000159         0.999603
# 49                62%          2    0.000159         0.999762
# 50                29%          2    0.000159         0.999921
# 51                43%          1    0.000079         1.000000
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       8859    0.702593         0.702593
# 1                 t       3750    0.297407         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      12466    0.988659         0.988659
# 1                      f        143    0.011341         1.000000
#
# ----------------------------------------------------------------
#
#                          neighbourhood  frequency  percentage  cumulative_perc
# 0                  Mexico City, Mexico       6692    0.530732         0.530732
# 1                    Tas-Sliema, Malta        497    0.039416         0.570148
# 2             San Pawl il-Baħar, Malta        456    0.036165         0.606313
# 3                      Il-Gżira, Malta        330    0.026172         0.632485
# 4                        Sliema, Malta        272    0.021572         0.654057
# ..                                 ...        ...         ...              ...
# 414  Iż-Żebbuġ, marsalforn Gozo, Malta          1    0.000079         0.999683
# 415       Floriana, La Valletta, Malta          1    0.000079         0.999762
# 416        Valletta, Tas-Sliema, Malta          1    0.000079         0.999841
# 417                 Rabat, Gozo, Malta          1    0.000079         0.999921
# 418                  Mgarr, N/A, Malta          1    0.000079         1.000000
#
# [419 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       6422    0.509319         0.509319
# 1   Private room in rental unit       1264    0.100246         0.609565
# 2                   Entire home        762    0.060433         0.669998
# 3                  Entire condo        609    0.048299         0.718296
# 4          Private room in home        508    0.040289         0.758585
# ..                          ...        ...         ...              ...
# 62         Private room in dome          1    0.000079         0.999683
# 63       Shared room in pension          1    0.000079         0.999762
# 64      Private room in cottage          1    0.000079         0.999841
# 65        Private room in train          1    0.000079         0.999921
# 66                 Earthen home          1    0.000079         1.000000
#
# [67 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       8902    0.706004         0.706004
# 1     Private room       3239    0.256880         0.962884
# 2      Shared room        382    0.030296         0.993179
# 3       Hotel room         86    0.006821         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       4759    0.377429         0.377429
# 1             2 baths       3181    0.252280         0.629709
# 2      1 private bath       1401    0.111111         0.740820
# 3       1 shared bath        792    0.062812         0.803632
# 4           1.5 baths        608    0.048220         0.851852
# 5             3 baths        524    0.041558         0.893409
# 6           2.5 baths        224    0.017765         0.911175
# 7             4 baths        204    0.016179         0.927353
# 8      2 shared baths        166    0.013165         0.940519
# 9    1.5 shared baths        109    0.008645         0.949163
# 10            5 baths        106    0.008407         0.957570
# 11          3.5 baths        100    0.007931         0.965501
# 12          4.5 baths         55    0.004362         0.969863
# 13     3 shared baths         49    0.003886         0.973749
# 14          Half-bath         41    0.003252         0.977001
# 15            6 baths         40    0.003172         0.980173
# 16     5 shared baths         37    0.002934         0.983107
# 17            0 baths         27    0.002141         0.985249
# 18          5.5 baths         26    0.002062         0.987311
# 19     0 shared baths         22    0.001745         0.989055
# 20   2.5 shared baths         22    0.001745         0.990800
# 21          6.5 baths         13    0.001031         0.991831
# 22            7 baths         13    0.001031         0.992862
# 23  Private half-bath         12    0.000952         0.993814
# 24   Shared half-bath         12    0.000952         0.994766
# 25     4 shared baths         12    0.000952         0.995717
# 26            8 baths          9    0.000714         0.996431
# 27          7.5 baths          8    0.000634         0.997066
# 28   5.5 shared baths          6    0.000476         0.997541
# 29           10 baths          4    0.000317         0.997859
# 30   7.5 shared baths          4    0.000317         0.998176
# 31   4.5 shared baths          4    0.000317         0.998493
# 32     6 shared baths          3    0.000238         0.998731
# 33   3.5 shared baths          3    0.000238         0.998969
# 34            9 baths          2    0.000159         0.999128
# 35          8.5 baths          2    0.000159         0.999286
# 36     8 shared baths          1    0.000079         0.999366
# 37          9.5 baths          1    0.000079         0.999445
# 38    19 shared baths          1    0.000079         0.999524
# 39         11.5 baths          1    0.000079         0.999603
# 40           15 baths          1    0.000079         0.999683
# 41           11 baths          1    0.000079         0.999762
# 42           16 baths          1    0.000079         0.999841
# 43     7 shared baths          1    0.000079         0.999921
# 44           12 baths          1    0.000079         1.000000
#
# ----------------------------------------------------------------
#
#                                                amenities  frequency  \
# 0      ["Air conditioning", "Wifi", "TV", "Kitchen", ...         50
# 1      ["Air conditioning", "Wifi", "TV", "Kitchen", ...         25
# 2      ["Pets allowed", "Fire extinguisher", "Wifi", ...         22
# 3      ["Hair dryer", "Heating", "Bed linens", "Wine ...         20
# 4      ["Air conditioning", "Fire extinguisher", "Wif...         17
# ...                                                  ...        ...
# 11526  ["Exercise equipment: free weights, yoga mat",...          1
# 11527  ["Air conditioning", "Fire extinguisher", "Wif...          1
# 11528  ["Mosquito net", "Kitchen", "Self check-in", "...          1
# 11529  ["Oven", "Hair dryer", "Heating", "Barbecue ut...          1
# 11530  ["Air conditioning", "Free parking on premises...          1
#
#        percentage  cumulative_perc
# 0        0.003965         0.003965
# 1        0.001983         0.005948
# 2        0.001745         0.007693
# 3        0.001586         0.009279
# 4        0.001348         0.010627
# ...           ...              ...
# 11526    0.000079         0.999683
# 11527    0.000079         0.999762
# 11528    0.000079         0.999841
# 11529    0.000079         0.999921
# 11530    0.000079         1.000000
#
# [11531 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      12608    0.999921         0.999921
# 1                f          1    0.000079         1.000000
#
# ----------------------------------------------------------------
#
#      first_review  frequency  percentage  cumulative_perc
# 0      23/01/2025       2061    0.163455         0.163455
# 1      2024-04-28         39    0.003093         0.166548
# 2      2024-04-14         34    0.002696         0.169244
# 3      2024-08-17         34    0.002696         0.171941
# 4      2024-08-21         32    0.002538         0.174479
# ...           ...        ...         ...              ...
# 2573   2018-03-04          1    0.000079         0.999683
# 2574   2018-03-16          1    0.000079         0.999762
# 2575   2018-02-26          1    0.000079         0.999841
# 2576   2018-02-07          1    0.000079         0.999921
# 2577   2024-09-24          1    0.000079         1.000000
#
# [2578 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#     last_review  frequency  percentage  cumulative_perc
# 0    24/01/2025       2061    0.163455         0.163455
# 1    2024-09-15        244    0.019351         0.182806
# 2    2024-09-08        232    0.018400         0.201205
# 3    2024-09-21        227    0.018003         0.219209
# 4    2024-09-22        225    0.017844         0.237053
# ..          ...        ...         ...              ...
# 957  2018-09-05          1    0.000079         0.999683
# 958  2017-08-05          1    0.000079         0.999762
# 959  2022-06-06          1    0.000079         0.999841
# 960  2018-08-10          1    0.000079         0.999921
# 961  2024-01-19          1    0.000079         1.000000
#
# [962 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                t       7237    0.573955         0.573955
# 1                f       5372    0.426045         1.000000
#
# ----------------------------------------------------------------
#
#    region_id  frequency  percentage  cumulative_perc
# 0    MT01259       1666    0.132128         0.132128
# 1    MT01555       1330    0.105480         0.237608
# 2    MT01252       1293    0.102546         0.340154
# 3    MT01221        870    0.068998         0.409152
# 4    MT01260        691    0.054802         0.463954
# ..       ...        ...         ...              ...
# 62   MT01351         13    0.001031         0.997383
# 63   MT01331         13    0.001031         0.998414
# 64   MT01432         10    0.000793         0.999207
# 65   MT01468          6    0.000476         0.999683
# 66   MT01340          4    0.000317         1.000000
#
# [67 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#           region_name  frequency  percentage  cumulative_perc
# 0              Sliema       1666    0.132128         0.132128
# 1   San Pawl il-Bahar       1330    0.105480         0.237608
# 2          San Giljan       1293    0.102546         0.340154
# 3               Gzira        870    0.068998         0.409152
# 4              Swieqi        691    0.054802         0.463954
# ..                ...        ...         ...              ...
# 62               Safi         13    0.001031         0.997383
# 63             Kirkop         13    0.001031         0.998414
# 64               Lija         10    0.000793         0.999207
# 65             Mtarfa          6    0.000476         0.999683
# 66             Mqabba          4    0.000317         1.000000
#
# [67 rows x 4 columns]
#
# ----------------------------------------------------------------

# %% [markdown]
# **PASO 3. Extraer características a partir de aplicar un análisis univariado, a diferentes variables categóricas.**

# %%
#Obtengo análisis univariado de una variable categórica en específico
table1=freq_tbl(df['listing_url'])
table1
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/50188          1
# 1      https://www.airbnb.com/rooms/1029420514294269216          1
# 2      https://www.airbnb.com/rooms/1029520809475335209          1
# 3      https://www.airbnb.com/rooms/1029633246045276883          1
# 4      https://www.airbnb.com/rooms/1029791534903536257          1
# ...                                                 ...        ...
# 12604             https://www.airbnb.com/rooms/53931502          1
# 12605             https://www.airbnb.com/rooms/53945539          1
# 12606             https://www.airbnb.com/rooms/53946097          1
# 12607             https://www.airbnb.com/rooms/53946234          1
# 12608  https://www.airbnb.com/rooms/1250838221147721892          1
#
#        percentage  cumulative_perc
# 0        0.000079         0.000079
# 1        0.000079         0.000159
# 2        0.000079         0.000238
# 3        0.000079         0.000317
# 4        0.000079         0.000397
# ...           ...              ...
# 12604    0.000079         0.999683
# 12605    0.000079         0.999762
# 12606    0.000079         0.999841
# 12607    0.000079         0.999921
# 12608    0.000079         1.000000
#
# [12609 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table2=freq_tbl(df['name'])
table2
# Out:
#                                                     name  frequency  \
# 0      1BR sensation, Fully equipped with In/Outdoor ...         25
# 1               Charming Room in Sliema Creek Guesthouse         21
# 2      St Julians, Indoor/Outdoor Pool, LUX ROOM & Views         17
# 3         Seafront, LUX Room with IN/OUTdoor pool heaven         16
# 4             Double Room/Studio in the Center of Sliema         13
# ...                                                  ...        ...
# 12068                           City Central Apartment 1          1
# 12069  Central Room ★ 5Mins to Valletta ★ Best Bus Ro...          1
# 12070                           City Central Apartment 2          1
# 12071                                     Pandora's loft          1
# 12072                       Luxury 3 rooms for 6 persons          1
#
#        percentage  cumulative_perc
# 0        0.001983         0.001983
# 1        0.001665         0.003648
# 2        0.001348         0.004996
# 3        0.001269         0.006265
# 4        0.001031         0.007296
# ...           ...              ...
# 12068    0.000079         0.999683
# 12069    0.000079         0.999762
# 12070    0.000079         0.999841
# 12071    0.000079         0.999921
# 12072    0.000079         1.000000
#
# [12073 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table3=freq_tbl(df['description'])
table3
# Out:
#                                              description  frequency  \
# 0                          No se proporciona descripción        210
# 1      The whole group will enjoy easy access to ever...         73
# 2      Enjoy a stylish experience at this centrally-l...         43
# 3      Keep it simple at this peaceful and centrally-...         42
# 4      Your family will be close to everything when y...         36
# ...                                                  ...        ...
# 10368  Large 2 bedroom apartment, in the old part of ...          1
# 10369  Look no further, one of a KIND APT with probab...          1
# 10370  Experience the history of the Old City in an e...          1
# 10371  WE ARE A PROFESSIONAL PROPERTY MANAGEMENT COMP...          1
# 10372  These are 3 rooms on ground level, forming par...          1
#
#        percentage  cumulative_perc
# 0        0.016655         0.016655
# 1        0.005790         0.022444
# 2        0.003410         0.025855
# 3        0.003331         0.029186
# 4        0.002855         0.032041
# ...           ...              ...
# 10368    0.000079         0.999683
# 10369    0.000079         0.999762
# 10370    0.000079         0.999841
# 10371    0.000079         0.999921
# 10372    0.000079         1.000000
#
# [10373 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table4=freq_tbl(df['neighborhood_overview'])
table4
# Out:
#                                   neighborhood_overview  frequency  \
# 0                           No se proporcionan detalles       6692
# 1     Sliema is a town located on the northeast coas...        128
# 2     This property is located in a quiet local neig...         58
# 3     The village of St. Julian’s (locally referred ...         42
# 4     St. Paul's is surrounded by breathtaking coast...         40
# ...                                                 ...        ...
# 4004  The property is located in the old town centre...          1
# 4005  Alvin’s home is located in Marsalforn, Island ...          1
# 4006  - Bugibba Square<br />- Shops/Bar/Restaurants ...          1
# 4007  The property is located in the center of Gharb...          1
# 4008  Renowned for its picturesque promenade, St Jul...          1
#
#       percentage  cumulative_perc
# 0       0.530732         0.530732
# 1       0.010151         0.540883
# 2       0.004600         0.545483
# 3       0.003331         0.548814
# 4       0.003172         0.551987
# ...          ...              ...
# 4004    0.000079         0.999683
# 4005    0.000079         0.999762
# 4006    0.000079         0.999841
# 4007    0.000079         0.999921
# 4008    0.000079         1.000000
#
# [4009 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table5=freq_tbl(df['picture_url'])
table5
# Out:
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/d3a0ac57-59f6...         16
# 1      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 2      https://a0.muscache.com/pictures/miso/Hosting-...         10
# 3      https://a0.muscache.com/pictures/hosting/Hosti...         10
# 4      https://a0.muscache.com/pictures/hosting/Hosti...          9
# ...                                                  ...        ...
# 12018  https://a0.muscache.com/pictures/miso/Hosting-...          1
# 12019  https://a0.muscache.com/pictures/4fd07f69-f5ef...          1
# 12020  https://a0.muscache.com/pictures/2ab79aee-9725...          1
# 12021  https://a0.muscache.com/pictures/miso/Hosting-...          1
# 12022  https://a0.muscache.com/pictures/hosting/Hosti...          1
#
#        percentage  cumulative_perc
# 0        0.001269         0.001269
# 1        0.000952         0.002221
# 2        0.000793         0.003014
# 3        0.000793         0.003807
# 4        0.000714         0.004521
# ...           ...              ...
# 12018    0.000079         0.999683
# 12019    0.000079         0.999762
# 12020    0.000079         0.999841
# 12021    0.000079         0.999921
# 12022    0.000079         1.000000
#
# [12023 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table6=freq_tbl(df['host_name'])
table6
# Out:
#                        host_name  frequency  percentage  cumulative_perc
# 0     Matthew ThreeSixty Estates        540    0.042827         0.042827
# 1                          Aaron        197    0.015624         0.058450
# 2                         Andrea        146    0.011579         0.070029
# 3                         Joseph        117    0.009279         0.079308
# 4                         Zzzing        112    0.008883         0.088191
# ...                          ...        ...         ...              ...
# 2052                       Diego          1    0.000079         0.999683
# 2053                     Saviour          1    0.000079         0.999762
# 2054                  Anna Marie          1    0.000079         0.999841
# 2055                      Mayara          1    0.000079         0.999921
# 2056                    Кароліна          1    0.000079         1.000000
#
# [2057 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table7=freq_tbl(df['host_since'])
table7
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     2022-09-02        456    0.036165         0.036165
# 1     2012-05-23        190    0.015069         0.051233
# 2     2019-12-18        112    0.008883         0.060116
# 3     2017-02-28        110    0.008724         0.068840
# 4     2021-01-20        100    0.007931         0.076771
# ...          ...        ...         ...              ...
# 2663  2016-10-25          1    0.000079         0.999683
# 2664  2022-09-10          1    0.000079         0.999762
# 2665  2022-09-08          1    0.000079         0.999841
# 2666  2015-05-06          1    0.000079         0.999921
# 2667  2011-05-31          1    0.000079         1.000000
#
# [2668 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table8=freq_tbl(df['host_response_time'])
table8
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       9413    0.746530         0.746530
# 1         Desconocido       1278    0.101356         0.847886
# 2  within a few hours        943    0.074788         0.922674
# 3        within a day        643    0.050995         0.973670
# 4  a few days or more        332    0.026330         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table9=freq_tbl(df['host_response_rate'])
table9
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%       8410    0.666984         0.666984
# 1                  -%       1278    0.101356         0.768340
# 2                 95%        489    0.038782         0.807122
# 3                 98%        432    0.034261         0.841383
# 4                 90%        325    0.025775         0.867158
# 5                 99%        292    0.023158         0.890316
# 6                 97%        192    0.015227         0.905544
# 7                  0%        145    0.011500         0.917043
# 8                 80%        112    0.008883         0.925926
# 9                 75%         81    0.006424         0.932350
# 10                50%         71    0.005631         0.937981
# 11                10%         59    0.004679         0.942660
# 12                96%         56    0.004441         0.947101
# 13                93%         56    0.004441         0.951543
# 14                94%         49    0.003886         0.955429
# 15                20%         45    0.003569         0.958998
# 16                79%         44    0.003490         0.962487
# 17                88%         41    0.003252         0.965739
# 18                70%         40    0.003172         0.968911
# 19                92%         39    0.003093         0.972004
# 20                86%         39    0.003093         0.975097
# 21                67%         35    0.002776         0.977873
# 22                30%         34    0.002696         0.980569
# 23                83%         23    0.001824         0.982394
# 24                91%         22    0.001745         0.984138
# 25                56%         21    0.001665         0.985804
# 26                89%         20    0.001586         0.987390
# 27                60%         20    0.001586         0.988976
# 28                40%         13    0.001031         0.990007
# 29                87%         11    0.000872         0.990880
# 30                72%         10    0.000793         0.991673
# 31                85%          9    0.000714         0.992386
# 32                57%          8    0.000634         0.993021
# 33                13%          8    0.000634         0.993655
# 34                82%          8    0.000634         0.994290
# 35                65%          8    0.000634         0.994924
# 36                33%          7    0.000555         0.995479
# 37                78%          7    0.000555         0.996035
# 38                15%          6    0.000476         0.996510
# 39                77%          6    0.000476         0.996986
# 40                64%          6    0.000476         0.997462
# 41                71%          6    0.000476         0.997938
# 42                14%          4    0.000317         0.998255
# 43                73%          3    0.000238         0.998493
# 44                58%          3    0.000238         0.998731
# 45                25%          3    0.000238         0.998969
# 46                11%          3    0.000238         0.999207
# 47                81%          3    0.000238         0.999445
# 48                17%          2    0.000159         0.999603
# 49                62%          2    0.000159         0.999762
# 50                29%          2    0.000159         0.999921
# 51                43%          1    0.000079         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table10=freq_tbl(df['host_is_superhost'])
table10
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       8859    0.702593         0.702593
# 1                 t       3750    0.297407         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table11=freq_tbl(df['host_identity_verified'])
table11
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      12466    0.988659         0.988659
# 1                      f        143    0.011341         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table12=freq_tbl(df['neighbourhood'])
table12
# Out:
#                          neighbourhood  frequency  percentage  cumulative_perc
# 0                  Mexico City, Mexico       6692    0.530732         0.530732
# 1                    Tas-Sliema, Malta        497    0.039416         0.570148
# 2             San Pawl il-Baħar, Malta        456    0.036165         0.606313
# 3                      Il-Gżira, Malta        330    0.026172         0.632485
# 4                        Sliema, Malta        272    0.021572         0.654057
# ..                                 ...        ...         ...              ...
# 414  Iż-Żebbuġ, marsalforn Gozo, Malta          1    0.000079         0.999683
# 415       Floriana, La Valletta, Malta          1    0.000079         0.999762
# 416        Valletta, Tas-Sliema, Malta          1    0.000079         0.999841
# 417                 Rabat, Gozo, Malta          1    0.000079         0.999921
# 418                  Mgarr, N/A, Malta          1    0.000079         1.000000
#
# [419 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table14=freq_tbl(df['property_type'])
table14
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       6422    0.509319         0.509319
# 1   Private room in rental unit       1264    0.100246         0.609565
# 2                   Entire home        762    0.060433         0.669998
# 3                  Entire condo        609    0.048299         0.718296
# 4          Private room in home        508    0.040289         0.758585
# ..                          ...        ...         ...              ...
# 62         Private room in dome          1    0.000079         0.999683
# 63       Shared room in pension          1    0.000079         0.999762
# 64      Private room in cottage          1    0.000079         0.999841
# 65        Private room in train          1    0.000079         0.999921
# 66                 Earthen home          1    0.000079         1.000000
#
# [67 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table15=freq_tbl(df['room_type'])
table15
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       8902    0.706004         0.706004
# 1     Private room       3239    0.256880         0.962884
# 2      Shared room        382    0.030296         0.993179
# 3       Hotel room         86    0.006821         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table16=freq_tbl(df['bathrooms_text'])
table16
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       4759    0.377429         0.377429
# 1             2 baths       3181    0.252280         0.629709
# 2      1 private bath       1401    0.111111         0.740820
# 3       1 shared bath        792    0.062812         0.803632
# 4           1.5 baths        608    0.048220         0.851852
# 5             3 baths        524    0.041558         0.893409
# 6           2.5 baths        224    0.017765         0.911175
# 7             4 baths        204    0.016179         0.927353
# 8      2 shared baths        166    0.013165         0.940519
# 9    1.5 shared baths        109    0.008645         0.949163
# 10            5 baths        106    0.008407         0.957570
# 11          3.5 baths        100    0.007931         0.965501
# 12          4.5 baths         55    0.004362         0.969863
# 13     3 shared baths         49    0.003886         0.973749
# 14          Half-bath         41    0.003252         0.977001
# 15            6 baths         40    0.003172         0.980173
# 16     5 shared baths         37    0.002934         0.983107
# 17            0 baths         27    0.002141         0.985249
# 18          5.5 baths         26    0.002062         0.987311
# 19     0 shared baths         22    0.001745         0.989055
# 20   2.5 shared baths         22    0.001745         0.990800
# 21          6.5 baths         13    0.001031         0.991831
# 22            7 baths         13    0.001031         0.992862
# 23  Private half-bath         12    0.000952         0.993814
# 24   Shared half-bath         12    0.000952         0.994766
# 25     4 shared baths         12    0.000952         0.995717
# 26            8 baths          9    0.000714         0.996431
# 27          7.5 baths          8    0.000634         0.997066
# 28   5.5 shared baths          6    0.000476         0.997541
# 29           10 baths          4    0.000317         0.997859
# 30   7.5 shared baths          4    0.000317         0.998176
# 31   4.5 shared baths          4    0.000317         0.998493
# 32     6 shared baths          3    0.000238         0.998731
# 33   3.5 shared baths          3    0.000238         0.998969
# 34            9 baths          2    0.000159         0.999128
# 35          8.5 baths          2    0.000159         0.999286
# 36     8 shared baths          1    0.000079         0.999366
# 37          9.5 baths          1    0.000079         0.999445
# 38    19 shared baths          1    0.000079         0.999524
# 39         11.5 baths          1    0.000079         0.999603
# 40           15 baths          1    0.000079         0.999683
# 41           11 baths          1    0.000079         0.999762
# 42           16 baths          1    0.000079         0.999841
# 43     7 shared baths          1    0.000079         0.999921
# 44           12 baths          1    0.000079         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table17=freq_tbl(df['amenities'])
table17
# Out:
#                                                amenities  frequency  \
# 0      ["Air conditioning", "Wifi", "TV", "Kitchen", ...         50
# 1      ["Air conditioning", "Wifi", "TV", "Kitchen", ...         25
# 2      ["Pets allowed", "Fire extinguisher", "Wifi", ...         22
# 3      ["Hair dryer", "Heating", "Bed linens", "Wine ...         20
# 4      ["Air conditioning", "Fire extinguisher", "Wif...         17
# ...                                                  ...        ...
# 11526  ["Exercise equipment: free weights, yoga mat",...          1
# 11527  ["Air conditioning", "Fire extinguisher", "Wif...          1
# 11528  ["Mosquito net", "Kitchen", "Self check-in", "...          1
# 11529  ["Oven", "Hair dryer", "Heating", "Barbecue ut...          1
# 11530  ["Air conditioning", "Free parking on premises...          1
#
#        percentage  cumulative_perc
# 0        0.003965         0.003965
# 1        0.001983         0.005948
# 2        0.001745         0.007693
# 3        0.001586         0.009279
# 4        0.001348         0.010627
# ...           ...              ...
# 11526    0.000079         0.999683
# 11527    0.000079         0.999762
# 11528    0.000079         0.999841
# 11529    0.000079         0.999921
# 11530    0.000079         1.000000
#
# [11531 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table18=freq_tbl(df['has_availability'])
table18
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      12608    0.999921         0.999921
# 1                f          1    0.000079         1.000000

# %%
#Obtengo análisis univariado de una variable categórica en específico
table19=freq_tbl(df['first_review'])
table19
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0      23/01/2025       2061    0.163455         0.163455
# 1      2024-04-28         39    0.003093         0.166548
# 2      2024-04-14         34    0.002696         0.169244
# 3      2024-08-17         34    0.002696         0.171941
# 4      2024-08-21         32    0.002538         0.174479
# ...           ...        ...         ...              ...
# 2573   2018-03-04          1    0.000079         0.999683
# 2574   2018-03-16          1    0.000079         0.999762
# 2575   2018-02-26          1    0.000079         0.999841
# 2576   2018-02-07          1    0.000079         0.999921
# 2577   2024-09-24          1    0.000079         1.000000
#
# [2578 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table20=freq_tbl(df['last_review'])
table20
# Out:
#     last_review  frequency  percentage  cumulative_perc
# 0    24/01/2025       2061    0.163455         0.163455
# 1    2024-09-15        244    0.019351         0.182806
# 2    2024-09-08        232    0.018400         0.201205
# 3    2024-09-21        227    0.018003         0.219209
# 4    2024-09-22        225    0.017844         0.237053
# ..          ...        ...         ...              ...
# 957  2018-09-05          1    0.000079         0.999683
# 958  2017-08-05          1    0.000079         0.999762
# 959  2022-06-06          1    0.000079         0.999841
# 960  2018-08-10          1    0.000079         0.999921
# 961  2024-01-19          1    0.000079         1.000000
#
# [962 rows x 4 columns]

# %%
#Obtengo análisis univariado de una variable categórica en específico
table21=freq_tbl(df['instant_bookable'])
table21
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                t       7237    0.573955         0.573955
# 1                f       5372    0.426045         1.000000

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table1_2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
table1_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f1= table1_2[table1_2['frequency']>0]
f1
#Ajusto el índice de mi dataframe
F1_index= f1.set_index('listing_url')
F1_index
# Out:
#                                                   frequency
# listing_url
# https://www.airbnb.com/rooms/50188                        1
# https://www.airbnb.com/rooms/1029420514294269216          1
# https://www.airbnb.com/rooms/1029520809475335209          1
# https://www.airbnb.com/rooms/1029633246045276883          1
# https://www.airbnb.com/rooms/1029791534903536257          1
# ...                                                     ...
# https://www.airbnb.com/rooms/53931502                     1
# https://www.airbnb.com/rooms/53945539                     1
# https://www.airbnb.com/rooms/53946097                     1
# https://www.airbnb.com/rooms/53946234                     1
# https://www.airbnb.com/rooms/1250838221147721892          1
#
# [12609 rows x 1 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table1.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table2_2= table2.drop(['percentage', 'cumulative_perc'], axis=1)
table2_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f2= table2_2[table2_2['frequency']>15]
f2
#Ajusto el índice de mi dataframe
F2_index= f2.set_index('name')
F2_index
# Out:
#                                                     frequency
# name
# 1BR sensation, Fully equipped with In/Outdoor Pool         25
# Charming Room in Sliema Creek Guesthouse                   21
# St Julians, Indoor/Outdoor Pool, LUX ROOM & Views          17
# Seafront, LUX Room with IN/OUTdoor pool heaven             16

# %%
#Realizamos grafico de barras del dataframe filtrado
F2_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Nombre')
plt.xlabel('Tipo de Nombres')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table3_2= table3.drop(['percentage', 'cumulative_perc'], axis=1)
table3_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f3= table3_2[table3_2['frequency']>50]
f3
#Ajusto el índice de mi dataframe
F3_index= f3.set_index('description')
F3_index
# Out:
#                                                     frequency
# description
# No se proporciona descripción                             210
# The whole group will enjoy easy access to every...         73

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table3.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table4_2= table4.drop(['percentage', 'cumulative_perc'], axis=1)
table4_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f4= table4_2[table4_2['frequency']>40]
f4
#Ajusto el índice de mi dataframe
F4_index= f4.set_index('neighborhood_overview')
F4_index
# Out:
#                                                     frequency
# neighborhood_overview
# No se proporcionan detalles                              6692
# Sliema is a town located on the northeast coast...        128
# This property is located in a quiet local neigh...         58
# The village of St. Julian’s (locally referred t...         42

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table4.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table5_2= table5.drop(['percentage', 'cumulative_perc'], axis=1)
table5_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f5= table5_2[table5_2['frequency']>7]
f5
#Ajusto el índice de mi dataframe
F5_index= f5.set_index('picture_url')
F5_index
# Out:
#                                                     frequency
# picture_url
# https://a0.muscache.com/pictures/d3a0ac57-59f6-...         16
# https://a0.muscache.com/pictures/miso/Hosting-4...         12
# https://a0.muscache.com/pictures/miso/Hosting-6...         10
# https://a0.muscache.com/pictures/hosting/Hostin...         10
# https://a0.muscache.com/pictures/hosting/Hostin...          9
# https://a0.muscache.com/pictures/hosting/Hostin...          8
# https://a0.muscache.com/pictures/miso/Hosting-9...          8

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table5.plot("frequency","cumulative_perc", kind= "scatter",color= "darkblue")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table6_2= table6.drop(['percentage', 'cumulative_perc'], axis=1)
table6_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f6= table6_2[table6_2['frequency']>200]
f6
#Ajusto el índice de mi dataframe
F6_index= f6.set_index('host_name')
F6_index
# Out:
#                             frequency
# host_name
# Matthew ThreeSixty Estates        540

# %%
#Realizamos grafico de área del dataframe filtrado
F6_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "purple")
# Out:
# <Axes: xlabel='host_name'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table7_2= table7.drop(['percentage', 'cumulative_perc'], axis=1)
table7_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f7= table7_2[table7_2['frequency']>100]
f7
#Ajusto el índice de mi dataframe
F7_index= f7.set_index('host_since')
F7_index
# Out:
#             frequency
# host_since
# 2022-09-02        456
# 2012-05-23        190
# 2019-12-18        112
# 2017-02-28        110

# %%
#Realizamos grafico de barras del dataframe filtrado
F7_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Antigüedad del anfitrión')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table8_2= table8.drop(['percentage', 'cumulative_perc'], axis=1)
table8_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f8= table8_2[table8_2['frequency']>0]
f8
#Ajusto el índice de mi dataframe
F8_index= f8.set_index('host_response_time')
F8_index
# Out:
#                     frequency
# host_response_time
# within an hour           9413
# Desconocido              1278
# within a few hours        943
# within a day              643
# a few days or more        332

# %%
#Realizamos grafico de barras del dataframe filtrado
F8_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Tiempo que tarda un anfitrión ')
plt.xlabel('Tiempos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table9_2= table9.drop(['percentage', 'cumulative_perc'], axis=1)
table9_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f9= table9_2[table9_2['frequency']>180]
f9
#Ajusto el índice de mi dataframe
F9_index= f9.set_index('host_response_rate')
F9_index
# Out:
#                     frequency
# host_response_rate
# 100%                     8410
# -%                       1278
# 95%                       489
# 98%                       432
# 90%                       325
# 99%                       292
# 97%                       192

# %%
#Realizamos grafico de área del dataframe filtrado
F9_index.plot(kind='area', figsize=(15,4),alpha= 0.5, color= "darkblue")
# Out:
# <Axes: xlabel='host_response_rate'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table10_2= table10.drop(['percentage', 'cumulative_perc'], axis=1)
table10_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f10= table10_2[table10_2['frequency']>100]
f10
#Ajusto el índice de mi dataframe
F10_index= f10.set_index('host_is_superhost')
F10_index
# Out:
#                    frequency
# host_is_superhost
# f                       8859
# t                       3750

# %%
#Realizamos grafico de pastel del dataframe filtrado
F10_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table11_2= table11.drop(['percentage', 'cumulative_perc'], axis=1)
table11_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f11= table11_2[table11_2['frequency']>1000]
f11
#Ajusto el índice de mi dataframe
F11_index= f11.set_index('host_identity_verified')
F11_index
# Out:
#                         frequency
# host_identity_verified
# t                           12466

# %%
#Realizamos grafico de pastel del dataframe filtrado
F11_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table12_2= table12.drop(['percentage', 'cumulative_perc'], axis=1)
table12_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f12= table12_2[table12_2['frequency']>100]
f12
#Ajusto el índice de mi dataframe
F12_index= f12.set_index('neighbourhood')
F12_index
# Out:
#                           frequency
# neighbourhood
# Mexico City, Mexico            6692
# Tas-Sliema, Malta               497
# San Pawl il-Baħar, Malta        456
# Il-Gżira, Malta                 330
# Sliema, Malta                   272
# San Ġiljan, Malta               268
# Il-Mellieħa, Malta              219
# Valletta, Malta                 184
# Is-Swieqi, Malta                171
# Il-Belt Valletta, Malta         141
# Saint Julian's, Malta           129
# Ix-Xagħra, Malta                123
# St. Julian's, Malta             108
# Wied il-Għajn, Malta            108

# %%
#Realizamos grafico de barras del dataframe filtrado
F12_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Vecindario ')
plt.xlabel('Nombres de Vecindarios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table14_2= table14.drop(['percentage', 'cumulative_perc'], axis=1)
table14_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f14= table14_2[table14_2['frequency']>500]
f14
#Ajusto el índice de mi dataframe
F14_index= f14.set_index('property_type')
F14_index
# Out:
#                              frequency
# property_type
# Entire rental unit                6422
# Private room in rental unit       1264
# Entire home                        762
# Entire condo                       609
# Private room in home               508

# %%
#Realizamos grafico de barras del dataframe filtrado
F14_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Propiedades ')
plt.xlabel('Tipos de Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table15_2= table15.drop(['percentage', 'cumulative_perc'], axis=1)
table15_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f15= table15_2[table15_2['frequency']>0]
f15
#Ajusto el índice de mi dataframe
F15_index= f15.set_index('room_type')
F15_index
# Out:
#                  frequency
# room_type
# Entire home/apt       8902
# Private room          3239
# Shared room            382
# Hotel room              86

# %%
#Realizamos grafico de barras del dataframe filtrado
F15_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Recámaras')
plt.xlabel('Tipos de Recámaras')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table16_2= table16.drop(['percentage', 'cumulative_perc'], axis=1)
table16_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f16= table16_2[table16_2['frequency']>300]
f16
#Ajusto el índice de mi dataframe
F16_index= f16.set_index('bathrooms_text')
F16_index
# Out:
#                 frequency
# bathrooms_text
# 1 bath               4759
# 2 baths              3181
# 1 private bath       1401
# 1 shared bath         792
# 1.5 baths             608
# 3 baths               524

# %%
#Realizamos grafico de pastel del dataframe filtrado
F16_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table17_2= table17.drop(['percentage', 'cumulative_perc'], axis=1)
table17_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f17= table17_2[table17_2['frequency']>18]
f17
#Ajusto el índice de mi dataframe
F17_index= f17.set_index('amenities')
F17_index
# Out:
#                                                     frequency
# amenities
# ["Air conditioning", "Wifi", "TV", "Kitchen", "...         50
# ["Air conditioning", "Wifi", "TV", "Kitchen", "...         25
# ["Pets allowed", "Fire extinguisher", "Wifi", "...         22
# ["Hair dryer", "Heating", "Bed linens", "Wine g...         20

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table17.plot("frequency","cumulative_perc", kind= "scatter",color= "purple")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table18_2= table18.drop(['percentage', 'cumulative_perc'], axis=1)
table18_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f18= table18_2[table18_2['frequency']>0]
f18
#Ajusto el índice de mi dataframe
F18_index= f18.set_index('has_availability')
F18_index
# Out:
#                   frequency
# has_availability
# t                     12608
# f                         1

# %%
#Realizamos grafico de pastel del dataframe filtrado
F18_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table19_2= table19.drop(['percentage', 'cumulative_perc'], axis=1)
table19_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f19= table19_2[table19_2['frequency']>80]
f19
#Ajusto el índice de mi dataframe
F19_index= f19.set_index('first_review')
F19_index
# Out:
#               frequency
# first_review
# 23/01/2025         2061

# %%
#Realizamos grafico de pastel del dataframe filtrado
F19_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table20_2= table20.drop(['percentage', 'cumulative_perc'], axis=1)
table20_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f20= table20_2[table20_2['frequency']>450]
f10
#Ajusto el índice de mi dataframe
F20_index= f20.set_index('last_review')
F20_index
# Out:
#              frequency
# last_review
# 24/01/2025        2061

# %%
#Realizamos grafico de pastel del dataframe filtrado
F20_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table21_2= table21.drop(['percentage', 'cumulative_perc'], axis=1)
table21_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f21= table21_2[table21_2['frequency']>0]
f21
#Ajusto el índice de mi dataframe
F21_index= f21.set_index('instant_bookable')
F21_index
# Out:
#                   frequency
# instant_bookable
# t                      7237
# f                      5372

# %%
#Realizamos grafico de pastel del dataframe filtrado
F21_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **PASO 4. Categorizar las siguientes variable**

# %% [markdown]
# **Determinación de clases para datos agrupados**

# %%
#Calculamos el numero total de la poblacion "n"
#df['accommodates'].info()
n=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max= df['accommodates'].max()
Min= df['accommodates'].min()
Limites=[Min, Max]
Limites
#Calcular el Rango R
R= Max-Min
R
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i= R/ni
i
# Out:
# 0.7010999808003474

# %%
#Calculamos el numero total de la poblacion "n"
df['beds'].info()
n2=26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12609 entries, 0 to 12608
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 12609 non-null  float64
# dtypes: float64(1)
# memory usage: 98.6 KB

# %%
#Obtenemos el límite superior e inferior de la columna objetivo
Max2= df['beds'].max()
Min2= df['beds'].min()
Limites2= [Min2,Max2]
Limites2
# Out:
# [0.0, 6.0]

# %%
#Calcular el Rango R
R2= Max2-Min2
R2
# Out:
# 6.0

# %%
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni2= 1+3.32*np.log10(n2)
ni2
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i2= R2/ni2
i2
# Out:
# 0.38241817134564404

# %%
#Calculamos el numero total de la poblacion "n"
#df['price'].info()
n3=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max3= df['price'].max()
Min3= df['price'].min()
Limites3=[Min3, Max3]
Limites3
#Calcular el Rango R
R3= Max3-Min3
R3
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni3= 1+3.32*np.log10(n3)
ni3
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i3= R3/ni3
i3
# Out:
# 15.551672301389523

# %%
#Calculamos el numero total de la poblacion "n"
#df['availability_365'].info()
n4=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max4= df['availability_365'].max()
Min4= df['availability_365'].min()
Limites4=[Min4, Max4]
Limites4
#Calcular el Rango R
R4= Max4-Min4
R4
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni4= 1+3.32*np.log10(n4)
ni4
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i4= R4/ni4
i4
# Out:
# 23.263772090193346

# %%
#Calculamos el numero total de la poblacion "n"
#df['number_of_reviews'].info()
n5=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max5= df['number_of_reviews'].max()
Min5= df['number_of_reviews'].min()
Limites5=[Min5, Max5]
Limites5
#Calcular el Rango R
R5= Max5-Min5
R5
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni5= 1+3.32*np.log10(n5)
ni5
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i5= R5/ni5
i5
# Out:
# 3.9516544372383215

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_location'].info()
n6=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max6= df['review_scores_location'].max()
Min6= df['review_scores_location'].min()
Limites6=[Min6, Max6]
Limites6
#Calcular el Rango R
R6= Max6-Min6
R6
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni6= 1+3.32*np.log10(n6)
ni6
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i6= R6/ni6
i6
# Out:
# 0.047802271418205505

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_value'].info()
n7=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max7= df['review_scores_value'].max()
Min7= df['review_scores_value'].min()
Limites7=[Min7, Max7]
Limites7
#Calcular el Rango R
R7= Max7-Min7
R7
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni7= 1+3.32*np.log10(n7)
ni7
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i7= R7/ni7
i7
# Out:
# 0.05672536208293718

# %%
#Calculamos el numero total de la poblacion "n"
#df['reviews_scores_communication'].info()
n8=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max8= df['review_scores_communication'].max()
Min8= df['review_scores_communication'].min()
Limites8=[Min8, Max8]
Limites8
#Calcular el Rango R
R8= Max8-Min8
R8
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni8= 1+3.32*np.log10(n8)
ni8
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i8= R8/ni8
i8
# Out:
# 0.02804399923201392

# %%
#Calculamos el numero total de la poblacion "n"
#df['reviews_per_month'].info()
n9=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max9= df['reviews_per_month'].max()
Min9= df['reviews_per_month'].min()
Limites9=[Min9, Max9]
Limites9
#Calcular el Rango R
R9= Max9-Min9
R9
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni9= 1+3.32*np.log10(n9)
ni9
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i9= R9/ni9
i9
# Out:
# 0.1873849039593656

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_checkin'].info()
n10=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max10= df['review_scores_checkin'].max()
Min10= df['review_scores_checkin'].min()
Limites10=[Min10, Max10]
Limites10
#Calcular el Rango R
R10= Max10-Min10
R10
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni10= 1+3.32*np.log10(n10)
ni10
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i10= R10/ni10
i10
# Out:
# 0.03186818094547034

# %%
#Calculamos el numero total de la poblacion "n"
#df['review_scores_accuracy'].info()
n11=26582
#Obtenemos el límite superior e inferior de la columna objetivo
Max11= df['review_scores_accuracy'].max()
Min11= df['review_scores_accuracy'].min()
Limites11=[Min11, Max11]
Limites11
#Calcular el Rango R
R11= Max11-Min11
R11
#Calculamos el número de intervalos de Clase "ni", aplicando la regla de Sturges
ni11= 1+3.32*np.log10(n11)
ni11
# Out:
# 15.689631010177528

# %%
#Calculamos el Ancho del Intervalo "i"
i11= R11/ni11
i11
# Out:
# 0.04461545332365848

# %% [markdown]
# **Creación de categorias/intervalos**

# %%
#Categorización de variables
intervalos=np.linspace(Min,Max,16)
intervalos
# Out:
# array([ 1.        ,  1.73333333,  2.46666667,  3.2       ,  3.93333333,
#         4.66666667,  5.4       ,  6.13333333,  6.86666667,  7.6       ,
#         8.33333333,  9.06666667,  9.8       , 10.53333333, 11.26666667,
#        12.        ])

# %%
#Creamos las categorías
categorias= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['accommodates']= pd.cut(x=df['accommodates'],bins=intervalos,labels=categorias)
df['accommodates']
# Out:
# 0          Categoria7
# 1          Categoria2
# 2        Categorias10
# 3          Categoria5
# 4          Categoria2
#              ...
# 12604      Categoria6
# 12605      Categoria2
# 12606      Categoria5
# 12607      Categoria7
# 12608      Categoria7
# Name: accommodates, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos2=np.linspace(Min2,Max2,16)
intervalos2
# Out:
# array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. , 4.4, 4.8,
#        5.2, 5.6, 6. ])

# %%
#Creamos las categorías
categorias2= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['beds']= pd.cut(x=df['beds'],bins=intervalos2,labels=categorias2)
df['beds']
# Out:
# 0          Categoria8
# 1          Categoria3
# 2          Categoria6
# 3          Categoria8
# 4          Categoria5
#              ...
# 12604      Categoria8
# 12605      Categoria3
# 12606      Categoria5
# 12607    Categorias10
# 12608    Categorias10
# Name: beds, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos3=np.linspace(Min3,Max3,16)
intervalos3
# Out:
# array([  8.        ,  24.26666667,  40.53333333,  56.8       ,
#         73.06666667,  89.33333333, 105.6       , 121.86666667,
#        138.13333333, 154.4       , 170.66666667, 186.93333333,
#        203.2       , 219.46666667, 235.73333333, 252.        ])

# %%
#Creamos las categorías
categorias3= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categorias9","Categorias10","Categorias11","Categorias12","Categorias13","Categorias14","Categorias15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['price']= pd.cut(x=df['price'],bins=intervalos3,labels=categorias3)
df['price']
# Out:
# 0        Categorias10
# 1          Categoria6
# 2          Categoria5
# 3          Categoria3
# 4          Categoria3
#              ...
# 12604    Categorias10
# 12605      Categoria3
# 12606      Categoria5
# 12607      Categoria8
# 12608      Categoria4
# Name: price, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categorias12' < 'Categorias13' < 'Categorias14' < 'Categorias15']

# %%
#Categorización de variables
intervalos4=np.linspace(Min4,Max4,16)
intervalos4
# Out:
# array([  0.        ,  24.33333333,  48.66666667,  73.        ,
#         97.33333333, 121.66666667, 146.        , 170.33333333,
#        194.66666667, 219.        , 243.33333333, 267.66666667,
#        292.        , 316.33333333, 340.66666667, 365.        ])

# %%
#Creamos las categorías
categorias4= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['availability_365']= pd.cut(x=df['availability_365'],bins=intervalos4,labels=categorias4)
df['availability_365']
# Out:
# 0         Categoria6
# 1         Categoria2
# 2        Categoria14
# 3        Categoria14
# 4        Categoria14
#             ...
# 12604    Categoria15
# 12605    Categoria15
# 12606    Categoria12
# 12607     Categoria5
# 12608    Categoria15
# Name: availability_365, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos5=np.linspace(Min5,Max5,16)
intervalos5
# Out:
# array([ 0.        ,  4.13333333,  8.26666667, 12.4       , 16.53333333,
#        20.66666667, 24.8       , 28.93333333, 33.06666667, 37.2       ,
#        41.33333333, 45.46666667, 49.6       , 53.73333333, 57.86666667,
#        62.        ])

# %%
#Creamos las categorías
categorias5= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['number_of_reviews']= pd.cut(x=df['number_of_reviews'],bins=intervalos5,labels=categorias5)
df['number_of_reviews']
# Out:
# 0         Categoria3
# 1         Categoria3
# 2        Categoria12
# 3         Categoria3
# 4         Categoria3
#             ...
# 12604            NaN
# 12605            NaN
# 12606            NaN
# 12607            NaN
# 12608            NaN
# Name: number_of_reviews, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos6=np.linspace(Min6,Max6,16)
intervalos6
# Out:
# array([4.25, 4.3 , 4.35, 4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75,
#        4.8 , 4.85, 4.9 , 4.95, 5.  ])

# %%
#Creamos las categorías
categorias6= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_location']= pd.cut(x=df['review_scores_location'],bins=intervalos6,labels=categorias6)
df['review_scores_location']
# Out:
# 0         Categoria8
# 1        Categoria15
# 2         Categoria6
# 3        Categoria12
# 4        Categoria11
#             ...
# 12604     Categoria9
# 12605     Categoria9
# 12606     Categoria9
# 12607     Categoria9
# 12608     Categoria9
# Name: review_scores_location, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos7=np.linspace(Min7,Max7,16)
intervalos7
# Out:
# array([4.11      , 4.16933333, 4.22866667, 4.288     , 4.34733333,
#        4.40666667, 4.466     , 4.52533333, 4.58466667, 4.644     ,
#        4.70333333, 4.76266667, 4.822     , 4.88133333, 4.94066667,
#        5.        ])

# %%
#Creamos las categorías
categorias7= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_value']= pd.cut(x=df['review_scores_value'],bins=intervalos7,labels=categorias7)
df['review_scores_value']
# Out:
# 0        Categoria12
# 1        Categoria10
# 2        Categoria12
# 3        Categoria14
# 4        Categoria10
#             ...
# 12604     Categoria9
# 12605     Categoria9
# 12606     Categoria9
# 12607     Categoria9
# 12608     Categoria9
# Name: review_scores_value, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos8=np.linspace(Min8,Max8,16)
intervalos8
# Out:
# array([4.56      , 4.58933333, 4.61866667, 4.648     , 4.67733333,
#        4.70666667, 4.736     , 4.76533333, 4.79466667, 4.824     ,
#        4.85333333, 4.88266667, 4.912     , 4.94133333, 4.97066667,
#        5.        ])

# %%
#Creamos las categorías
categorias8= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_communication']= pd.cut(x=df['review_scores_communication'],bins=intervalos8,labels=categorias8)
df['review_scores_communication']
# Out:
# 0        Categoria14
# 1        Categoria14
# 2        Categoria13
# 3        Categoria13
# 4        Categoria12
#             ...
# 12604    Categoria15
# 12605    Categoria15
# 12606    Categoria15
# 12607    Categoria15
# 12608    Categoria15
# Name: review_scores_communication, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos9=np.linspace(Min9,Max9,16)
intervalos9
# Out:
# array([0.01 , 0.206, 0.402, 0.598, 0.794, 0.99 , 1.186, 1.382, 1.578,
#        1.774, 1.97 , 2.166, 2.362, 2.558, 2.754, 2.95 ])

# %%
#Creamos las categorías
categorias9= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['reviews_per_month']= pd.cut(x=df['reviews_per_month'],bins=intervalos9,labels=categorias9)
df['reviews_per_month']
# Out:
# 0        Categoria7
# 1        Categoria6
# 2        Categoria2
# 3        Categoria4
# 4        Categoria7
#             ...
# 12604    Categoria7
# 12605    Categoria7
# 12606    Categoria7
# 12607    Categoria7
# 12608    Categoria7
# Name: reviews_per_month, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos10=np.linspace(Min10,Max10,16)
intervalos10
# Out:
# array([4.5       , 4.53333333, 4.56666667, 4.6       , 4.63333333,
#        4.66666667, 4.7       , 4.73333333, 4.76666667, 4.8       ,
#        4.83333333, 4.86666667, 4.9       , 4.93333333, 4.96666667,
#        5.        ])

# %%
#Creamos las categorías
categorias10= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_checkin']= pd.cut(x=df['review_scores_checkin'],bins=intervalos10,labels=categorias10)
df['review_scores_checkin']
# Out:
# 0        Categoria14
# 1        Categoria14
# 2        Categoria12
# 3        Categoria14
# 4        Categoria11
#             ...
# 12604    Categoria15
# 12605    Categoria15
# 12606    Categoria15
# 12607    Categoria15
# 12608    Categoria15
# Name: review_scores_checkin, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %%
#Categorización de variables
intervalos11=np.linspace(Min11,Max11,16)
intervalos11
# Out:
# array([4.3       , 4.34666667, 4.39333333, 4.44      , 4.48666667,
#        4.53333333, 4.58      , 4.62666667, 4.67333333, 4.72      ,
#        4.76666667, 4.81333333, 4.86      , 4.90666667, 4.95333333,
#        5.        ])

# %%
#Creamos las categorías
categorias11= ["Categoria1","Categoria2","Categoria3","Categoria4","Categoria5","Categoria6","Categoria7","Categoria8","Categoria9","Categoria10","Categoria11","Categoria12","Categoria13","Categoria14","Categoria15"]

# %%
#Finalmente creamos las categorías en la columna numérica
df['review_scores_accuracy']= pd.cut(x=df['review_scores_accuracy'],bins=intervalos11,labels=categorias11)
df['review_scores_accuracy']
# Out:
# 0        Categoria14
# 1        Categoria12
# 2        Categoria11
# 3        Categoria13
# 4         Categoria9
#             ...
# 12604     Categoria9
# 12605     Categoria9
# 12606     Categoria9
# 12607     Categoria9
# 12608     Categoria9
# Name: review_scores_accuracy, Length: 12609, dtype: category
# Categories (15, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' ... 'Categoria12' < 'Categoria13' < 'Categoria14' < 'Categoria15']

# %% [markdown]
# **Creamos gráficas y tablas de las categoricas recién creadas**

# %%
#Obtego análidsis univariado de una variable categórica en específico
table22= freq_tbl(df['accommodates'])
table22
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table22_2= table22.drop(['percentage', 'cumulative_perc'], axis=1)
table22_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f22= table22_2[table22_2['frequency']>0]
f22
#Ajusto el índice de mi dataframe
F22_index= f22.set_index('accommodates')
F22_index
# Out:
#               frequency
# accommodates
# Categoria2         4079
# Categoria5         3002
# Categoria7         1783
# Categoria3          977
# Categoria6          820
# Categorias10        521
# Categorias9         323
# Categorias13        207
# Categorias11        149
# Categorias15         92
# Categorias14         63

# %%
#Realizamos grafico de barras del dataframe filtrado
F22_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "darkblue")
plt.title('Máximo de Huespedes')
plt.xlabel('Cantidad de huespedes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table23= freq_tbl(df['beds'])
table23
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table23_2= table23.drop(['percentage', 'cumulative_perc'], axis=1)
table23_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f23= table23_2[table23_2['frequency']>0]
f23
#Ajusto el índice de mi dataframe
F23_index= f23.set_index('beds')
F23_index
# Out:
#               frequency
# beds
# Categoria3         3710
# Categoria5         3327
# Categoria8         2014
# Categorias10       1336
# Categorias13        693
# Categoria6          570
# Categorias15        530

# %%
#Realizamos grafico de barras del dataframe filtrado
F23_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Camas')
plt.xlabel('Cantidad de camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table24= freq_tbl(df['price'])
table24
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table24_2= table24.drop(['percentage', 'cumulative_perc'], axis=1)
table24_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f24= table24_2[table24_2['frequency']>400]
f24
#Ajusto el índice de mi dataframe
F24_index= f24.set_index('price')
F24_index
# Out:
#               frequency
# price
# Categoria6         2409
# Categoria5         1527
# Categoria4         1486
# Categoria8         1273
# Categoria3         1209
# Categoria7         1106
# Categoria2          862
# Categorias9         707
# Categorias10        431

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table24.plot("frequency","cumulative_perc", kind= "scatter",color= "green")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table25= freq_tbl(df['availability_365'])
table25
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table25_2= table25.drop(['percentage', 'cumulative_perc'], axis=1)
table25_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f25= table25_2[table25_2['frequency']>800]
f25
#Ajusto el índice de mi dataframe
F25_index= f25.set_index('availability_365')
F25_index
# Out:
#                   frequency
# availability_365
# Categoria15            2319
# Categoria14            1416
# Categoria12            1049
# Categoria11             966
# Categoria13             862

# %%
#Realizamos grafico de área del dataframe filtrado
F25_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "darkblue")
# Out:
# <Axes: xlabel='availability_365'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table26= freq_tbl(df['number_of_reviews'])
table26
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table26_2= table26.drop(['percentage', 'cumulative_perc'], axis=1)
table26_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f26= table26_2[table26_2['frequency']>500]
f26
#Ajusto el índice de mi dataframe
F26_index= f26.set_index('number_of_reviews')
F26_index
# Out:
#                    frequency
# number_of_reviews
# Categoria1              3075
# Categoria3              2380
# Categoria2              1527
# Categoria4               701
# Categoria5               531

# %%
#Realizamos grafico de pastel del dataframe filtrado
F26_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table27= freq_tbl(df['review_scores_location'])
table27
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table27_2= table27.drop(['percentage', 'cumulative_perc'], axis=1)
table27_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f27= table27_2[table27_2['frequency']>700]
f27
#Ajusto el índice de mi dataframe
F27_index= f27.set_index('review_scores_location')
F27_index
# Out:
#                         frequency
# review_scores_location
# Categoria9                   2773
# Categoria15                  2649
# Categoria11                  1670
# Categoria13                   932
# Categoria10                   786
# Categoria12                   782

# %%
#Realizamos grafico de pastel del dataframe filtrado
F27_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table28= freq_tbl(df['review_scores_value'])
table28
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table28_2= table28.drop(['percentage', 'cumulative_perc'], axis=1)
table28_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f28= table28_2[table28_2['frequency']>800]
f28
#Ajusto el índice de mi dataframe
F28_index= f28.set_index('review_scores_value')
F28_index
# Out:
#                      frequency
# review_scores_value
# Categoria9                2635
# Categoria15               2298
# Categoria10               1991
# Categoria13                985
# Categoria12                942
# Categoria11                932

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table28.plot("frequency","cumulative_perc", kind= "scatter",color= "green")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table29= freq_tbl(df['review_scores_communication'])
table29
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table29_2= table29.drop(['percentage', 'cumulative_perc'], axis=1)
table29_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f29= table29_2[table29_2['frequency']>800]
f29
#Ajusto el índice de mi dataframe
F29_index= f29.set_index('review_scores_communication')
F29_index
# Out:
#                              frequency
# review_scores_communication
# Categoria15                       6506
# Categoria12                       1961

# %%
#Realizamos grafico de área del dataframe filtrado
F29_index.plot(kind='area', figsize=(10,4),alpha= 0.5, color= "purple")
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table30= freq_tbl(df['reviews_per_month'])
table30
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table30_2= table30.drop(['percentage', 'cumulative_perc'], axis=1)
table30_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f30= table30_2[table30_2['frequency']>900]
f30
#Ajusto el índice de mi dataframe
F30_index= f30.set_index('reviews_per_month')
F30_index
# Out:
#                    frequency
# reviews_per_month
# Categoria7              2671
# Categoria6              1535
# Categoria1              1516
# Categoria2              1382
# Categoria3              1019
# Categoria4               996

# %%
#Realizamos grafico de barras del dataframe filtrado
F30_index.plot(kind = 'bar', width=.8, figsize=(10,4), color= "purple")
plt.title('Reseñas por mes')
plt.xlabel('Reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtego análidsis univariado de una variable categórica en específico
table31= freq_tbl(df['review_scores_checkin'])
table31
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table31_2= table31.drop(['percentage', 'cumulative_perc'], axis=1)
table31_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f31= table31_2[table31_2['frequency']>500]
f31
#Ajusto el índice de mi dataframe
F31_index= f31.set_index('review_scores_checkin')
F31_index
# Out:
#                        frequency
# review_scores_checkin
# Categoria15                 6069
# Categoria12                 1860
# Categoria14                  713
# Categoria13                  706
# Categoria11                  512

# %%
#Realizamos grafico de pastel del dataframe filtrado
F31_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtego análidsis univariado de una variable categórica en específico
table32= freq_tbl(df['review_scores_accuracy'])
table32
#Eliminamos columnas percentage y cumulative_perc para trabajar con las frecuencias
table32_2= table32.drop(['percentage', 'cumulative_perc'], axis=1)
table32_2
#Obtenemos un filtro de los valores más relevantes de la variable categórica seleccionada
f32= table32_2[table32_2['frequency']>0]
f32
#Ajusto el índice de mi dataframe
F32_index= f32.set_index('review_scores_accuracy')
F32_index
# Out:
#                         frequency
# review_scores_accuracy
# Categoria15                  3335
# Categoria9                   2483
# Categoria11                  1760
# Categoria13                  1035
# Categoria14                   929
# Categoria12                   628
# Categoria10                   565
# Categoria8                    525
# Categoria5                    426
# Categoria6                    226
# Categoria7                    224
# Categoria1                    136
# Categoria3                    124
# Categoria4                    119
# Categoria2                     76

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table32.plot("frequency","cumulative_perc", kind= "scatter",color= "darkblue")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>
